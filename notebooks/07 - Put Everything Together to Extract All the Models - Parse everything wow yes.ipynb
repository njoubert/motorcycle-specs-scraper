# %%
import pickle
import requests
from bs4 import BeautifulSoup
import re
import os
import os.path
import base64
import urllib.parse
import time

with open('mfct_urls.pickle', 'rb') as f:
    mfct_urls = pickle.load(f)
with open('expanded_urls.pickle', 'rb') as f:
    expanded_urls = pickle.load(f)
with open('all_models.pickle', 'rb') as f:
    all_models = pickle.load(f)

# %%
import collections
assert(len([item for item, count in collections.Counter(all_models).items() if count > 1]) == 0)

# %%
cache_dir = os.path.expanduser("cache/")

def retrieve_and_cache(url,verbose=False,session=None):
    # pass in a requests.Session() object if you want to make many calls, keeping the connection open.
    # This gives you a 2x speedup.
    
    # This caching has a MAJOR FLAW: It does not check whether the page has been updated.
    # Once downloaded, it will keep the file forever. 
    # This is acceptable since this is to aid development when I don't want to repeatedly hit the 
    # server and wait for a download, but, this is NOT well-suited for scraping the site to check for updates.
    # I suggest deleting the cache folder before doing a big scrape
    #
    # We can also try out CacheControl https://cachecontrol.readthedocs.io/en/latest/
    
    start_time = time.time()
    if not os.path.exists(cache_dir):
        if verbose:
            print("Initializing cache directory")
        os.makedirs(cache_dir)
    filename = urllib.parse.quote(url, '')
    filepath = os.path.join(cache_dir, filename)
    if verbose:
        print("Checking cache for", filename)
    raw_html = ""

    if os.path.exists(filepath):
        if verbose:
            print("  Retrieving from cache")
        with open(filepath, 'r') as file:
            raw_html = file.read()
    else:
        if verbose:
            print("  Fetching and saving to cache")
        response = None
        if session:
            response = session.get(url)
        else:
            response = requests.get(url)
        
        raw_html = response.text
        with open(filepath, 'x') as file:
            file.write(raw_html)
    if verbose:
        print("  Took", time.time() - start_time,"seconds")
    return raw_html

def dedupe_list_preserving_order(items):
    return list(dict.fromkeys(items))

def parse_table_to_dict(text,url=None): 
    # Parses the first Make-Model table we find on the page.
    # Returns an empty {} if we didn't find any data.
    soup = BeautifulSoup(text, 'lxml') # important to pip install lxml
    output = {}
    
    # Find the Table
    hook = soup.find_all(string=re.compile(".*Make Model.*"))
    if len(hook) == 0:
        return output
    if len(hook) > 1:
        print("Woah more than one \"Make Model\" entry, using the first one inside a table [",url,"]")
    assert(len(hook)>=1)  # Assert we find at least one NavigatableString containing "Make Model"
    table = None
    for h in hook: # Let's find the first one that is inside a table. 
        if h.find_parent('table'):
            table = h.find_parent('table')
            break
    assert(table) # We assert we did find one
    rows = table.find_all('tr')
    assert(len(rows) > 1) # Assert we've found and parsed a table with many rows
    
    # Extract the key:value pairs
    for row in rows:
        cols = row.find_all('td')
        if len(cols) != 2:
            print("We did not find 2 columns in this row, skipping... [", url, "]")
            continue
        assert(len(cols) == 2) # We expect two columns in each row, which we treat as a key:value pair
        key = cols[0].get_text().strip()
        value = cols[1].get_text().strip().replace("\t", "")
        output[key] = value
    return output

def decorate_table(table_dict, key_vals):
    return table_dict | key_vals

def get_mfct(name):
    for i, m in enumerate(mfct_urls):
        if m['mfct'] == name:
            return m
    return None
        
def clean_keys(table_dict,url=None):
    d = {}
    for k, v in table_dict.items():
        # Remove punctuation 
        k = k.translate(str.maketrans('', '', '!"#$%&\'()*+,-.:;<=>?@[\]^_`{|}~'))
        
        # Remove extraneous whitespace
        k = " ".join(k.split()).strip()
        
        # Ensure Title Case
        k = k.title()

        # Collapse certain special cases. DANGER, THIS WILL COLLIDE TABLE ENTRIES
        k = k.replace("Abs", "ABS")
        k = k.replace("Rear Wheels", "Rear Wheel")
        k = k.replace("Wheels Rear", "Rear Wheel")
        k = k.replace("Front Wheels", "Front Wheel")
        k = k.replace("Wheels Front", "Front Wheel")
        k = k.replace("Final Reduction Ratio", "Final Reduction")
        k = k.replace("Gear Ratios", "Gear Ratio")
        k = k.replace("Gear Tatio", "Gear Ratio")
        k = k.replace("Primary Reduction Ratio", "Primary Reduction")
        k = k.replace("Dryweight", "Dry Weight")
        k = k.replace("Dry Weight /", "Dry Weight")
        k = k.replace("Wetweight", "Wet Weight")
        k = k.replace("Wet Wight", "Wet Weight")
        k = k.replace("We Weight", "Wet Weight")
        k = k.replace("Final Srive", "Final Drive")
        k = k.replace("Final Drice", "Final Drive")
        k = k.replace("Final Ldrive", "Final Drive")
        #k = k.replace("Final Driv", "Final Drive")  # I NEED REGEX HERE ELSE WE PLURIFY EVERYTHING
        #k = k.replace("Dimension", "Dimensions")    # I NEED REGEX HERE ELSE WE PLURIFY EVERYTHING
        k = k.replace("Seat Hieght", "Seat Height")
        k = k.replace("Seat Heigth", "Seat Height")
        k = k.replace("Gouun Clearance", "Ground Clearance")
        k = k.replace("Staring", "Starting")
        k = k.replace("Rear Wheel Travcel", "Rear Wheel Travel")
        k = k.replace("Front Wheel Travlel", "Front Wheel Travel")
        k = k.replace("Lubricationn", "Lubrication")
        
        
        
        # Save the new key
        if k in d:
            # Combine entries if there's a colliding key. If no collision, we ignore.
            if d[k].strip() != v.strip():
                #print("Found colliding entries for key", k, "combining old value [",d[k],"] and new value [",v,"] for",url)
                d[k] = d[k] + " | " + v
        else:
            d[k] = v
                
        
    return d

def clean_vals(table_dict,url=None):
    d = {}
    for k, v in table_dict.items():
        # Remove extraneous whitespace
        v = " ".join(v.split()).strip()

        # Save the new key
        d[k] = v
        
    return d

def clean_model_table(table_dict,url=None):
    return clean_vals(clean_keys(table_dict,url=url),url=url)

# %%
def get_table_for_url(url, return_empty_tables=True):
    raw_html = retrieve_and_cache(url)
    table_dict = parse_table_to_dict(raw_html,url=url)
    if table_dict == {} and not return_empty_tables:
        return {}
    table_dict_decorated = decorate_table(table_dict, {"Link":url})
    table_dict_decorated_cleaned = clean_model_table(table_dict_decorated,url=url)
    return table_dict_decorated_cleaned

# %%
def get_all_model_tables_for_mfct(mfct_name):
    m = get_mfct(mfct_name)
    tables = []
    for url in m['models']:
        table = get_table_for_url(url, return_empty_tables=False)
        if table != {}:
            tables.append(table)
    return tables

# %%
cleaned_tables = get_all_model_tables_for_mfct('Kawasaki')
# Out:
# We did not find 2 columns in this row, skipping... [ https://www.motorcyclespecs.co.za/model/kawasaki/kawasaki_s3_400%2075.htm ]
# We did not find 2 columns in this row, skipping... [ https://www.motorcyclespecs.co.za/model/kawasaki/kawasaki_s3_400%2075.htm ]

# %%
import pandas as pd
df = pd.DataFrame(cleaned_tables)
df
# Out:
#                                      Make Model       Year  \
# 0                       Kawasaki 250 A1 Samurai  1966 - 68
# 1                       Kawasaki 250 A1 Samurai   1969 -71
# 2                                Kawasaki AR 50  1981 - 96
# 3                                Kawasaki AR 80   1981 -83
# 4                                Kawasaki AR 80     1984 -
# ...                                         ...        ...
# 999                 Kawasaki ZZ-R 1200 / ZX-12C       2004
# 1000                Kawasaki ZZ-R 1200 / ZX-12C       2005
# 1001  Kawasaki ZZR 1400 (ZX-14) Special Edition       2007
# 1002        Kawasaki ZZR 1400 Performance Sport       2014
# 1003           Kawasaki ZZR 1400 / Ninja ZX-14R  2021 - 22
#
#                                                  Engine  \
# 0      Two-stroke, parallel twin, 2 rotary inlet valves
# 1      Two-stroke, parallel twin, 2 rotary inlet valves
# 2              Two stroke, single cylinder, disc valve.
# 3              Two stroke, single cylinder, disc valve.
# 4              Two stroke, single cylinder, disc valve.
# ...                                                 ...
# 999   Four stroke, transverse four cylinder, DOHC, 4...
# 1000  Four stroke, transverse four cylinder, DOHC, 4...
# 1001  Four stroke, transverse four cylinders, DOHC, ...
# 1002  Four stroke, transverse four cylinders, DOHC, ...
# 1003  Four stroke, transverse four cylinders, DOHC, ...
#
#                                   Capacity Bore X Stroke Cooling System  \
# 0                      247 cc / 15.1 cu-in  53 x 56.0 mm     Air cooled
# 1                      247 cc / 15.1 cu-in  53 x 56.0 mm     Air cooled
# 2                        49 cc / 3.0 cu-in  49 x 41.6 mm     Air cooled
# 3                      79.4 cc / 4.8 cu-in  49 x 41.6 mm     Air cooled
# 4                      79.4 cc / 4.8 cu-in  49 x 41.6 mm     Air cooled
# ...                                    ...           ...            ...
# 999                   1164 cc / 71.0 cu-in    78 x 59 mm  Liquid cooled
# 1000                  1164 cc / 71.0 cu-in    78 x 59 mm  Liquid cooled
# 1001                  1441 cc / 87.9 cu-in    84 x 65 mm  Liquid cooled
# 1002  1441 cc / 87.9 cu-in cc / 87.9 cu-in    84 x 65 mm  Liquid cooled
# 1003                  1441 cc / 87.9 cu-in    84 x 65 mm  Liquid cooled
#
#      Compression Ratio                                   Induction  \
# 0                7.0:1                                  Carburetor
# 1                7.0:1                                  Carburetor
# 2                7.8:1                    Mikuni VM18SC Carburetor
# 3                7.8:1                    Mikuni VM18SC Carburetor
# 4                7.8:1                    Mikuni VM18SC Carburetor
# ...                ...                                         ...
# 999             10.6:1                       4x Keihin CVKD40, TPS
# 1000            10.6:1                       4x Keihin CVKD40, TPS
# 1001            12.3:1  DFI® with four 44mm Mikuni throttle bodies
# 1002            12.3:1  DFI® with four 44mm Mikuni throttle bodies
# 1003            12.3:1   DFI with four 44mm Mikuni throttle bodies
#
#                           Ignition  Starting  ... Reviews Standing 0 100Km  \
# 0     Capacitor discharge ignition      Kick  ...     NaN              NaN
# 1     Capacitor discharge ignition      Kick  ...     NaN              NaN
# 2              Capacitor discharge      Kick  ...     NaN              NaN
# 3              Capacitor discharge      Kick  ...     NaN              NaN
# 4              Capacitor discharge      Kick  ...     NaN              NaN
# ...                            ...       ...  ...     ...              ...
# 999               Digital ignition  Electric  ...     NaN              NaN
# 1000              Digital ignition  Electric  ...     NaN              NaN
# 1001     TCBI with Digital Advance  Electric  ...     NaN              NaN
# 1002     TCBI with Digital Advance  Electric  ...     NaN              NaN
# 1003     TCBI with Digital Advance  Electric  ...     NaN              NaN
#
#      Standing 0 140Km Standing 0 200Km Acceleration 60140 Km/H  \
# 0                 NaN              NaN                     NaN
# 1                 NaN              NaN                     NaN
# 2                 NaN              NaN                     NaN
# 3                 NaN              NaN                     NaN
# 4                 NaN              NaN                     NaN
# ...               ...              ...                     ...
# 999               NaN              NaN                     NaN
# 1000              NaN              NaN                     NaN
# 1001              NaN              NaN                     NaN
# 1002              NaN              NaN                     NaN
# 1003              NaN              NaN                     NaN
#
#      Acceleration 100 140 Km/H Acceleration 140 180 Km/H Firing Order  \
# 0                          NaN                       NaN          NaN
# 1                          NaN                       NaN          NaN
# 2                          NaN                       NaN          NaN
# 3                          NaN                       NaN          NaN
# 4                          NaN                       NaN          NaN
# ...                        ...                       ...          ...
# 999                        NaN                       NaN          NaN
# 1000                       NaN                       NaN          NaN
# 1001                       NaN                       NaN          NaN
# 1002                       NaN                       NaN          NaN
# 1003                       NaN                       NaN          NaN
#
#      Minimum Turning Circle Related Links
# 0                       NaN           NaN
# 1                       NaN           NaN
# 2                       NaN           NaN
# 3                       NaN           NaN
# 4                       NaN           NaN
# ...                     ...           ...
# 999                     NaN           NaN
# 1000                    NaN           NaN
# 1001                    NaN           NaN
# 1002                    NaN           NaN
# 1003                    NaN           NaN
#
# [1004 rows x 127 columns]

# %%
df.to_csv('kawi-no-empty.csv')

# %% [markdown]
# ## WARNING: THE CODE BELOW PROCESSES ALL 11k MODELS AND SAVES TO OVER 100 CSV FILES

# %%
all_tables = []
for i, mfct_name in enumerate([m['mfct'] for m in mfct_urls]):
    print("Processing", i,"of",len(mfct_urls)-1,":",mfct_name)
    cleaned_tables = get_all_model_tables_for_mfct(mfct_name)
    all_tables.extend(cleaned_tables)
    df = pd.DataFrame(cleaned_tables)
    mfct_urls[i]['df'] = df
    df.to_csv("models {index:03d} - {mfct_name}.csv".format(index = i, mfct_name=urllib.parse.quote(mfct_name,'')))
# Out:
# Processing 0 of 131 : AC Schnitzer
# Processing 1 of 131 : Adler
# Processing 2 of 131 : AJP
# Processing 3 of 131 : AJS
# Processing 4 of 131 : Alfer
# Processing 5 of 131 : Aprilia
# Found colliding entries for key Final Drive combining old value [ Chain ] and new value [ 17:40 ] for https://www.motorcyclespecs.co.za/model/aprilia/aprilia-rs125r-nero-06.html
# Found colliding entries for key Final Drive combining old value [ Chain ] and new value [ 17:40 ] for https://www.motorcyclespecs.co.za/model/aprilia/aprilia-rs125r-06.html
# Found colliding entries for key Final Drive combining old value [ Chain ] and new value [ 17:40 ] for https://www.motorcyclespecs.co.za/model/aprilia/aprilia-rs125r-07.html
# Found colliding entries for key Final Drive combining old value [ Chain ] and new value [ 17:40 ] for https://www.motorcyclespecs.co.za/model/aprilia/aprilia-rs125-lorenzo-07.html
# Found colliding entries for key Final Drive combining old value [ Chain ] and new value [ 17:40 ] for https://www.motorcyclespecs.co.za/model/aprilia/aprilia-rs125r-08.html
# Found colliding entries for key Final Drive combining old value [ Chain ] and new value [ 17:40 ] for https://www.motorcyclespecs.co.za/model/aprilia/aprilia-rs125r-rosso-fluo.html
# Found colliding entries for key Final Drive combining old value [ Chain ] and new value [ 17:40 ] for https://www.motorcyclespecs.co.za/model/aprilia/aprilia-rs125-standerd-09.html
# Found colliding entries for key Final Drive combining old value [ Chain ] and new value [ 17:40 ] for https://www.motorcyclespecs.co.za/model/aprilia/aprilia-rs125r-09.html
# Found colliding entries for key Final Drive combining old value [ Chain ] and new value [ 17:40 ] for https://www.motorcyclespecs.co.za/model/aprilia/aprilia-rs125-talmacsi-rep.html
# Found colliding entries for key Final Drive combining old value [ Chain ] and new value [ 17:40 ] for https://www.motorcyclespecs.co.za/model/aprilia/aprilia-rs125r-max-biaggi.html
# Found colliding entries for key Final Drive combining old value [ Chain ] and new value [ 17:40 ] for https://www.motorcyclespecs.co.za/model/aprilia/aprilia-rs125r-10.html
# Found colliding entries for key Final Drive combining old value [ Chain ] and new value [ 17:40 ] for https://www.motorcyclespecs.co.za/model/aprilia/aprilia-rs125r-full-black.html
# Found colliding entries for key Final Drive combining old value [ Chain ] and new value [ 17:40 ] for https://www.motorcyclespecs.co.za/model/aprilia/aprilia-rs125r-full-white.html
# Found colliding entries for key Final Drive combining old value [ Chain ] and new value [ 17:40 ] for https://www.motorcyclespecs.co.za/model/aprilia/aprilia-rs125r-10%20biagie%20rep.html
# Processing 6 of 131 : Ariel
# Processing 7 of 131 : Arlen Ness
# Woah more than one table at https://www.motorcyclespecs.co.za/model/Victory/victory_vision_Arlen%20Ness%2010.htm
# Processing 8 of 131 : ATK
# Processing 9 of 131 : Avinton / Wakan
# Processing 10 of 131 : Bajai
# Processing 11 of 131 : Bakker
# Processing 12 of 131 : Barigo
# Processing 13 of 131 : Benelli
# Processing 14 of 131 : Beta
# Processing 15 of 131 : Big Bear
# Processing 16 of 131 : Big Dog
# Processing 17 of 131 : Bimota
# Found colliding entries for key Seat Height combining old value [ 800mm / 31.5 in. ] and new value [ 790 mm / 31.1 in. ] for https://www.motorcyclespecs.co.za/model/bimota/bimota-db5.html
# Found colliding entries for key Seat Height combining old value [ 800mm / 31.5 in. ] and new value [ 790 mm / 31.1 in. ] for https://www.motorcyclespecs.co.za/model/bimota/bimota-db5-07.html
# Found colliding entries for key Cooling System combining old value [ Liquid cooled ] and new value [ Liquid ] for https://www.motorcyclespecs.co.za/model/bimota/bimota_sb8k%2004.htm
# Found colliding entries for key Cooling System combining old value [ Liquid cooled ] and new value [ Liquid ] for https://www.motorcyclespecs.co.za/model/bimota/bimota_sb8k_santa_monica.htm
# Processing 18 of 131 : BMS Choppers
# Processing 19 of 131 : BMW
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/bmw/bmw-r1200r-17.html
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/bmw/bmw-r1200r-17.html
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/bmw/bmw-r1200r-18.html
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/bmw/bmw-r1200r-18.html
# Processing 20 of 131 : Boss Hoss
# Processing 21 of 131 : Boxer
# Processing 22 of 131 : Brammo
# Processing 23 of 131 : Britten
# Processing 24 of 131 : Brixton Motorcycles
# Processing 25 of 131 : Brough Superior Motorcycles
# Processing 26 of 131 : BRP Cam-Am
# Processing 27 of 131 : BSA
# Processing 28 of 131 : Buell / EBR
# Processing 29 of 131 : Bultaco
# Processing 30 of 131 : Cagiva
# Processing 31 of 131 : Campagna
# Processing 32 of 131 : CCM
# Processing 33 of 131 : CF Moto
# Processing 34 of 131 : Confederate / Combat Motors
# Processing 35 of 131 : CR&S
# Processing 36 of 131 : CZ Motorcycles
# Processing 37 of 131 : Daelim
# Processing 38 of 131 : Derbi
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/Derbi/Derbi_Mulachen_Cafe_07.html
# Processing 39 of 131 : Deus
# Processing 40 of 131 : DP Customs
# Processing 41 of 131 : Ducati
# Found colliding entries for key Final Drive combining old value [ Chain ] and new value [ 2.706 ] for https://www.motorcyclespecs.co.za/model/ducati/ducati_98_sport_53.htm
# Found colliding entries for key Final Drive combining old value [ Chain ] and new value [ 3.066:1 ] for https://www.motorcyclespecs.co.za/model/ducati/Ducati_175_Americano.html
# Found colliding entries for key Final Drive combining old value [ Chain ] and new value [ 3.066:1 ] for https://www.motorcyclespecs.co.za/model/ducati/Ducati_175_ts.html
# Found colliding entries for key Final Drive combining old value [ Chain ] and new value [ 3.066:1 ] for https://www.motorcyclespecs.co.za/model/ducati/Ducati_175_ts_64.html
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/ducati/ducati_diavel%20Strada%2013.htm
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/ducati/ducati_diavel%20Strada%2013.htm
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/ducati/ducati_diavel%20strada%2014.htm
# Found colliding entries for key Exhaust combining old value [ 2-1 system with catalytic converter and two
# lambda  probes, Single stainless steel muffler with ] and new value [ Lightweight 2-1-2 system with catalytic
# converter with twin lambda probes ] for https://www.motorcyclespecs.co.za/model/ducati/ducati_monster_797_17.htm
# Found colliding entries for key Exhaust combining old value [ 2-1 system with catalytic converter and two
# lambda  probes, Single stainless steel muffler with ] and new value [ Lightweight 2-1-2 system with catalytic
# converter with twin lambda probes ] for https://www.motorcyclespecs.co.za/model/ducati/ducati_monster_797_se_18.html
# Found colliding entries for key Exhaust combining old value [ 2-1 system with catalytic converter and two
# lambda  probes, Single stainless steel muffler with ] and new value [ Lightweight 2-1-2 system with catalytic
# converter with twin lambda probes ] for https://www.motorcyclespecs.co.za/model/ducati/ducati_monster_797+_18.html
# Found colliding entries for key Exhaust combining old value [ 2-1 system with catalytic converter and two
# lambda  probes, Single stainless steel muffler with ] and new value [ Lightweight 2-1-2 system with catalytic
# converter with twin lambda probes ] for https://www.motorcyclespecs.co.za/model/ducati/ducati_monster_797_19.html
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/ducati/ducati_multistrada_950S_20_gp_white.html
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/ducati/ducati_multistrada_1200%20S%2010.htm
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/ducati/ducati_multistrada_1200%20S%2011.htm
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/ducati/ducati_multistrada_1200%20S%20pikes%20peak.htm
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/ducati/ducati_multistrada_1200%20S%2012.htm
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/ducati/ducati_multistrada_1200%20S%20pikes%20peak%2012.htm
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/ducati/ducati_multistrada_1200%20S%2013.htm
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/ducati/Ducati_Multistrada_1200S_Touring_13.html
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/ducati/ducati_multistrada_1200%20S%20GT%2013.htm
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/ducati/ducati_multistrada_1200%20S%20pikes%20peak%2013.htm
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/ducati/ducati_multistrada_1200%20SDolomites%20Peak%20Edition.htm
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/ducati/ducati_multistrada_1200%20S%2014.htm
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/ducati/Ducati_Multistrada_1200S_Touring_14.html
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/ducati/ducati_multistrada_1200%20S%20GT%2014.htm
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/ducati/ducati_multistrada_1200%20S%20pikes%20peak%2014.htm
# Processing 42 of 131 : Excelsior
# Processing 43 of 131 : Exile
# Processing 44 of 131 : GASGAS
# Processing 45 of 131 : Ghezzi Brian
# Processing 46 of 131 : Gilera
# Processing 47 of 131 : GIMA
# Processing 48 of 131 : Harley-Davidson
# Processing 49 of 131 : Harris
# Processing 50 of 131 : Hartford
# Processing 51 of 131 : HDT USA
# Processing 52 of 131 : Hesketh
# Processing 53 of 131 : Hero
# Processing 54 of 131 : Highland
# Processing 55 of 131 : Honda
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr1100xx_97.html
# Found colliding entries for key Standing ¼ Mile combining old value [ 11.1 sec / 193.0 km/h ] and new value [ 11.4 sec ] for https://www.motorcyclespecs.co.za/model/Honda/honda_vfr800_02.html
# Found colliding entries for key Consumption Average combining old value [ 15.9 km/lit ] and new value [ 18.0 km/lot ] for https://www.motorcyclespecs.co.za/model/Honda/honda_vfr800_abs_03.html
# Found colliding entries for key Standing ¼ Mile combining old value [ 11.1 sec / 193.0 km/h ] and new value [ 11.4 sec ] for https://www.motorcyclespecs.co.za/model/Honda/honda_vfr800_abs_03.html
# Found colliding entries for key Consumption Average combining old value [ 15.9 km/lit ] and new value [ 18.0 km/lot ] for https://www.motorcyclespecs.co.za/model/Honda/honda_vfr800_abs_04.html
# Found colliding entries for key Standing ¼ Mile combining old value [ 11.1 sec / 193.0 km/h ] and new value [ 11.4 sec ] for https://www.motorcyclespecs.co.za/model/Honda/honda_vfr800_abs_04.html
# Found colliding entries for key Standing ¼ Mile combining old value [ 11.1 sec / 193.0 km/h ] and new value [ 11.4 sec ] for https://www.motorcyclespecs.co.za/model/Honda/honda_vfr800_abs_05.html
# Found colliding entries for key Standing ¼ Mile combining old value [ 11.1 sec / 193.0 km/h ] and new value [ 11.4 sec ] for https://www.motorcyclespecs.co.za/model/Honda/honda_vfr800_vtec_06.html
# Processing 56 of 131 : Horex
# Processing 57 of 131 : HPN
# Processing 58 of 131 : Husaberg
# Processing 59 of 131 : Husqvarna
# Processing 60 of 131 : Hyosung
# Processing 61 of 131 : Indian
# Processing 62 of 131 : Italjet
# Processing 63 of 131 : Jawa
# Processing 64 of 131 : Junak
# Processing 65 of 131 : Kawasaki
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/kawasaki/kawasaki_s3_400%2075.htm
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/kawasaki/kawasaki_s3_400%2075.htm
# Found colliding entries for key Ground Clearance combining old value [ 1435 mm / 56.5 in. ] and new value [ 125 mm / 4.9 in ] for https://www.motorcyclespecs.co.za/model/kawasaki/kawasaki_z1000r_17.htm
# Found colliding entries for key Ground Clearance combining old value [ 1435 mm / 56.5 in. ] and new value [ 125 mm / 4.9 in ] for https://www.motorcyclespecs.co.za/model/kawasaki/kawasaki_z1000r_19.html
# Processing 66 of 131 : KTM
# Processing 67 of 131 : KYMCO
# Processing 68 of 131 : Laverda
# Processing 69 of 131 : Lazareth
# Processing 70 of 131 : Lehman Trikes
# Processing 71 of 131 : LIFAN
# Processing 72 of 131 : Lord Drake Kustoms
# Processing 73 of 131 : Magni
# Processing 74 of 131 : Maico
# Processing 75 of 131 : Mash
# Processing 76 of 131 : Matchless
# Processing 77 of 131 : Matt Hotch
# Processing 78 of 131 : Megelli
# Processing 79 of 131 : Midual
# Processing 80 of 131 : Mission
# Processing 81 of 131 : Molot
# Processing 82 of 131 : Mondial
# Processing 83 of 131 : Moto Guzzi
# Processing 84 of 131 : Moto Morini
# Processing 85 of 131 : Mr Martini
# Processing 86 of 131 : MTT
# Processing 87 of 131 : Münch
# Processing 88 of 131 : MV Agusta
# Found colliding entries for key Electronic Quickshift combining old value [ MV EAS 3.0 (Electronically Assisted Shift up & down) ] and new value [ MV EAS 2.0 (Electronically Assisted Shift up & down) ] for https://www.motorcyclespecs.co.za/model/mv/mv_agusta_brutale_800_ross_21.html
# Found colliding entries for key Electronic Quickshift combining old value [ MV EAS 3.0 (Electronically Assisted Shift up & down) ] and new value [ MV EAS 2.0 (Electronically Assisted Shift up & down) ] for https://www.motorcyclespecs.co.za/model/mv/mv_agusta_brutale_800rr_21.html
# Found colliding entries for key Electronic Quickshift combining old value [ MV EAS 3.0 (Electronically Assisted Shift up & down) ] and new value [ MV EAS 2.0 (Electronically Assisted Shift up & down) ] for https://www.motorcyclespecs.co.za/model/mv/mv_agusta_brutale_800rr_scs_21.html
# Found colliding entries for key Electronic Quickshift combining old value [ MV EAS 3.0 (Electronically Assisted Shift up & down) ] and new value [ MV EAS 2.0 (Electronically Assisted Shift up & down) ] for https://www.motorcyclespecs.co.za/model/mv/mv_agusta_dragster_800_rosso_21.html
# Found colliding entries for key Electronic Quickshift combining old value [ MV EAS 3.0 (Electronically Assisted Shift up & down) ] and new value [ MV EAS 2.0 (Electronically Assisted Shift up & down) ] for https://www.motorcyclespecs.co.za/model/mv/mv_agusta_dragster_800rr_21.html
# Found colliding entries for key Electronic Quickshift combining old value [ MV EAS 3.0 (Electronically Assisted Shift up & down) ] and new value [ MV EAS 2.0 (Electronically Assisted Shift up & down) ] for https://www.motorcyclespecs.co.za/model/mv/mv_agusta_dragster_800rr_scs_21.html
# Found colliding entries for key Electronic Quickshift combining old value [ MV EAS 3.0 (Electronically Assisted Shift up & down) ] and new value [ MV EAS 2.0 (Electronically Assisted Shift up & down) ] for https://www.motorcyclespecs.co.za/model/mv/mv_agusta_dragster_800rr_scs_london_sp.html
# Found colliding entries for key Electronic Quickshift combining old value [ MV EAS 3.0 (Electronically Assisted Shift up & down) ] and new value [ MV EAS 2.0 (Electronically Assisted Shift up & down) ] for https://www.motorcyclespecs.co.za/model/mv/mv_agusta_dragster_800rc_scs_21.html
# Found colliding entries for key Electronic Quickshift combining old value [ MV EAS 3.0 (Electronically Assisted Shift up & down) ] and new value [ MV EAS 2.0 (Electronically Assisted Shift up & down) ] for https://www.motorcyclespecs.co.za/model/mv/mv-agusta-dragster-800rc-scs-22.html
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/mv/mv-agusta-f3-800rc-22.html
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/mv/mv-agusta-f3-800rc-22.html
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/mv/mv_agusta_F4_Claudio.html
# Processing 89 of 131 : MZ / MuZ
# Processing 90 of 131 : NCR
# Processing 91 of 131 : Norton
# Processing 92 of 131 : NSU
# Processing 93 of 131 : OCC
# Processing 94 of 131 : Paton
# Processing 95 of 131 : Paul Jr. Designs
# Processing 96 of 131 : Peugeot
# Processing 97 of 131 : Piaggio
# Processing 98 of 131 : Revival Cycles
# Processing 99 of 131 : Rickman
# Processing 100 of 131 : Roehr
# Processing 101 of 131 : Roland Sands
# Processing 102 of 131 : Royal Enfield
# Processing 103 of 131 : Rucker
# Processing 104 of 131 : Sachs
# Processing 105 of 131 : Saxon
# Processing 106 of 131 : Shaw Speed
# Processing 107 of 131 : Sherco
# Processing 108 of 131 : Sunbeam
# Processing 109 of 131 : Suzuki
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/suzu/suzuki_gt250%2076.htm
# Found colliding entries for key Final Drive combining old value [ Shaft ] and new value [ 32/12 (2.6) ] for https://www.motorcyclespecs.co.za/model/suzu/suzuki_gv1400_cavalcade_gt.htm
# Found colliding entries for key Final Drive combining old value [ Shaft ] and new value [ 32/12 (2.6) ] for https://www.motorcyclespecs.co.za/model/suzu/suzuki_gv1400_cavalcade_lx.htm
# Found colliding entries for key Final Drive combining old value [ Shaft ] and new value [ 32/12 (2.6) ] for https://www.motorcyclespecs.co.za/model/suzu/suzuki_gv1400_lxe_cavalcade%2087.htm
# Processing 110 of 131 : SWM
# Processing 111 of 131 : SYM
# Processing 112 of 131 : Titan
# Processing 113 of 131 : TM Racing
# Processing 114 of 131 : Triumph
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/triu/Triumph_Street_Twin_19.html
# Processing 115 of 131 : TVS
# Processing 116 of 131 : Ural
# Processing 117 of 131 : Velocette
# Processing 118 of 131 : Vespa
# Found colliding entries for key Seat Height combining old value [ 775 mm / 30.5 in ] and new value [ 805 mm / 31.7 in ] for https://www.motorcyclespecs.co.za/model/Vespa/Vespa%20LX%2050%202T%2006.htm
# Processing 119 of 131 : Victory
# Woah more than one table at https://www.motorcyclespecs.co.za/model/Victory/victory_vision_Arlen%20Ness%2010.htm
# Processing 120 of 131 : Vilner
# Processing 121 of 131 : Vincent
# Processing 122 of 131 : VOR
# Processing 123 of 131 : Voxan
# Woah more than one table at https://www.motorcyclespecs.co.za/model/voxan/Voxan_GTV_1200.html
# Processing 124 of 131 : Vyrus
# Processing 125 of 131 : Walt Siegl
# Processing 126 of 131 : Walz
# Processing 127 of 131 : Wrenchmonkees
# Processing 128 of 131 : Wunderlich
# Processing 129 of 131 : XTR / Radical
# Processing 130 of 131 : Yamaha
# Processing 131 of 131 : Zero

# %% [markdown]
# # Combine all the tables into one giant table

# %%
df = pd.DataFrame(all_tables)

# %% [markdown]
# # Export to CSV

# %%
df.to_csv('ALL_MODELS.csv')

# %% [markdown]
# # Export to Excel
#
# Install the dependencies
#
# > pip install XlsxWriter

# %%
#with pd.ExcelWriter("ALL_MODELS.xlsx") as writer:
#    df.to_excel(writer, sheet_name="models", index=False)

with pd.ExcelWriter("models_on_sheets.xlsx") as writer:
    for m in mfct_urls:
        m['df'].to_excel(writer, sheet_name=urllib.parse.quote(m['mfct'],'')[0:31], index=False)

# %% [markdown]
# # Debugging

# %%
url = "https://www.motorcyclespecs.co.za/model/voxan/Voxan_GTV_1200.html"
raw_html = retrieve_and_cache(url)
table_dict = parse_table_to_dict(raw_html,url=url)
# Out:
# Woah more than one table at https://www.motorcyclespecs.co.za/model/voxan/Voxan_GTV_1200.html
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[133], line 3
#       1 url = "https://www.motorcyclespecs.co.za/model/voxan/Voxan_GTV_1200.html"
#       2 raw_html = retrieve_and_cache(url)
# ----> 3 table_dict = parse_table_to_dict(raw_html,url=url)
#
# Cell In[128], line 63, in parse_table_to_dict(text, url)
#      61 hook = hook[0] # For now we're only parsing the first one.
#      62 table = hook.find_parent('table')
# ---> 63 rows = table.find_all('tr')
#      64 assert(len(rows) > 1) # Assert we've found and parsed a table with many rows
#      66 # Extract the key:value pairs
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
soup = BeautifulSoup(raw_html, 'lxml') # important to pip install lxml
output = {}

# Find the Table
hook = soup.find_all(string=re.compile(".*Make Model.*"))
if len(hook) > 1:
    print("Woah more than one table at",url)
assert(len(hook)>=1)  # Assert we find at least one NavigatableString containing "Make Model"
for h in hook:
    if h.find_parent('table'):
        table = h.find_parent('table')
        break
table
# Out:
# Woah more than one table at https://www.motorcyclespecs.co.za/model/voxan/Voxan_GTV_1200.html
# <table height="821" id="table8" width="100%">
# <tr>
# <td class="xl24" height="39" style="border-style: solid" width="618">
# <p align="justify"><font face="Arial">Make Model</font></p></td>
# <td class="xl25" height="38" style="border-left-style: solid; border-left-width: medium; border-right-style: solid; border-top-style: solid; border-bottom-style: solid" width="1230">
# <font face="Arial">Voxan GTV 1200</font></td>
# </tr>
# <tr>
# <td class="xl24" height="39" style="border-left-style: solid; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="618">
# <p align="justify"><font face="Arial">Year</font></p></td>
# <td class="xl26" height="38" style="border-left-style: solid; border-left-width: medium; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="1230" x:num="">
# <font face="Arial">2010</font></td>
# </tr>
# <tr>
# <td class="xl24" height="39" style="border-left-style: solid; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="618">
# <p align="justify"><font face="Arial">Engine</font></p></td>
# <td class="xl26" height="38" style="border-left-style: solid; border-left-width: medium; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="1230">
# <font face="Arial">Four stoke, 72°V-Twin</font></td>
# </tr>
# <tr>
# <td class="xl24" height="39" style="border-left-style: solid; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="618">
# <p align="justify"><font face="Arial">Capacity</font></p></td>
# <td class="xl26" height="38" style="border-left-style: solid; border-left-width: medium; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="1230" x:num="">
# <font face="Arial">1166.5 cc</font></td>
# </tr>
# <tr>
# <td class="xl24" height="39" style="border-left-style: solid; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="618">
# <span style="font-weight: normal; font-family: Courier New">
# <font face="Arial">Bore x Stroke</font></span></td>
# <td class="xl27" height="38" style="border-left-style: solid; border-left-width: medium; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="1230">
# <font face="Arial">103 x 107 mm</font></td>
# </tr>
# <tr>
# <td class="xl24" height="39" style="border-left-style: solid; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="618">
#     Cooling System</td>
# <td class="xl27" height="38" style="border-left-style: solid; border-left-width: medium; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="1230">
# <font face="Arial">Liquid cooled</font></td>
# </tr>
# <tr>
# <td class="xl24" height="39" style="border-left-style: solid; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="618">
# <span style="font-weight: normal; font-family: Courier New">
# <font face="Arial">Compression Ratio</font></span></td>
# <td class="xl27" height="38" style="border-left-style: solid; border-left-width: medium; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="1230">
#     NA</td>
# </tr>
# <tr>
# <td class="xl24" height="39" style="border-left-style: solid; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="618">
# <p align="justify"><font face="Arial">Induction</font></p></td>
# <td class="xl27" height="38" style="border-left-style: solid; border-left-width: medium; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="1230">
# <font face="Arial">Electronically controlled fuel injectioned fuel
# 	injection</font></td>
# </tr>
# <tr>
# <td class="xl28" height="39" style="border-left-style: solid; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="618">
# <p align="justify"><font face="Arial">Ignition </font></p></td>
# <td class="xl26" height="39" style="border-left-style: solid; border-left-width: medium; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="1230">
# <font face="Arial">Electronic </font></td>
# </tr>
# <tr>
# <td class="xl24" height="39" style="border-left-style: solid; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="618">
# <font face="Arial">Starting</font></td>
# <td class="xl26" height="39" style="border-left-style: solid; border-left-width: medium; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="1230">
#     Electric</td>
# </tr>
# <tr>
# <td class="xl24" height="39" style="border-left-style: solid; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="618">
# <p align="justify"><font face="Arial">Max Power</font></p></td>
# <td class="xl26" height="39" style="border-left-style: solid; border-left-width: medium; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="1230">
# <font face="Arial">106 hp</font></td>
# </tr>
# <tr>
# <td class="xl24" height="39" style="border-left-style: solid; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="618">
# <p align="justify"><font face="Arial">Max Torque</font></p></td>
# <td class="xl26" height="39" style="border-left-style: solid; border-left-width: medium; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="1230">
#     NA</td>
# </tr>
# <tr>
# <td class="xl24" height="39" style="border-left-style: solid; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="618">
# <p align="justify"><font face="Arial">Transmission</font></p></td>
# <td class="xl26" height="39" style="border-left-style: solid; border-left-width: medium; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="1230">
# <font face="Arial">6 Speed </font></td>
# </tr>
# <tr>
# <td class="xl24" height="39" style="border-left-style: solid; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="618">
#     Final Drive</td>
# <td class="xl26" height="39" style="border-left-style: solid; border-left-width: medium; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="1230">
#     Belt</td>
# </tr>
# <tr>
# <td class="xl24" height="39" style="border-left-style: solid; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="618">
# <font face="Arial">Frame</font></td>
# <td class="xl26" height="39" style="border-left-style: solid; border-left-width: medium; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="1230">
# <font face="Arial">Trellis Frame</font></td>
# </tr>
# <tr>
# <td class="xl24" height="39" style="border-left-style: solid; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="618">
# <p align="justify"><font face="Arial">Front Suspension</font></p></td>
# <td class="xl26" height="39" style="border-left-style: solid; border-left-width: medium; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="1230">
# <font face="Arial">43mm Upside down hydraulic forks</font></td>
# </tr>
# <tr>
# <td class="xl24" height="39" style="border-left-style: solid; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="618">
# <p align="justify"><font face="Arial">Rear Suspension</font></p></td>
# <td class="xl26" height="39" style="border-left-style: solid; border-left-width: medium; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="1230">
#      </td>
# </tr>
# <tr>
# <td class="xl24" height="39" style="border-left-style: solid; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="618">
# <p align="justify"><font face="Arial">Front Brakes</font></p></td>
# <td class="xl26" height="39" style="border-left-style: solid; border-left-width: medium; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="1230">
# <font face="Arial">2x 320mm discs 4 piston calipers</font></td>
# </tr>
# <tr>
# <td class="xl24" height="39" style="border-left-style: solid; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="618">
# <p align="justify"><font face="Arial">Rear Brakes</font></p></td>
# <td class="xl26" height="39" style="border-left-style: solid; border-left-width: medium; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="1230">
# <font face="Arial">Single 245mm disc  2 piston caliper</font></td>
# </tr>
# <tr>
# <td class="xl24" height="39" style="border-left-style: solid; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="618">
# <p align="justify"><font face="Arial">Front Tyre</font></p></td>
# <td class="xl29" height="39" style="border-left-style: solid; border-left-width: medium; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="1230">
# <font face="Arial">120/70-17</font></td>
# </tr>
# <tr>
# <td class="xl24" height="39" style="border-left-style: solid; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="618">
# <p align="justify"><font face="Arial">Rear Tyre</font></p></td>
# <td class="xl29" height="39" style="border-left-style: solid; border-left-width: medium; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="1230">
# <font face="Arial">180/55-17</font></td>
# </tr>
# <tr>
# <td class="xl24" height="39" style="border-left-style: solid; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="618">
# <font face="Arial">Seat Height</font></td>
# <td class="xl26" height="39" style="border-left-style: solid; border-left-width: medium; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="1230">
#      </td>
# </tr>
# <tr>
# <td class="xl24" height="39" style="border-left-style: solid; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="618">
# <p align="justify"><font face="Arial">Dry Weight  </font></p></td>
# <td class="xl26" height="39" style="border-left-style: solid; border-left-width: medium; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="1230">
# <font face="Arial">179 kg</font></td>
# </tr>
# <tr>
# <td class="xl24" height="39" style="border-left-style: solid; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="618">
# <p align="justify"><font face="Arial">Fuel Capacity </font></p></td>
# <td class="xl26" height="39" style="border-left-style: solid; border-left-width: medium; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="1230">
# <font face="Arial">17 Litres</font></td>
# </tr>
# </table>

# %%
hook
# Out:
# ['Make Model', 'Make Model']

# %%
hook = hook[0] # For now we're only parsing the first one. 
table = hook.find_parent('table')
rows = table.find_all('tr')

# %%
import xlsxwriter

# %%
"hkjansdflkjnasdf"[0:31]
# Out:
# 'hkjansdflkjnasdf'
