# %%
import pickle
import requests
from bs4 import BeautifulSoup
import re
import os
import os.path
import base64
import urllib.parse
import time

with open('mfct_urls.pickle', 'rb') as f:
    mfct_urls = pickle.load(f)
with open('expanded_urls.pickle', 'rb') as f:
    expanded_urls = pickle.load(f)
with open('all_models.pickle', 'rb') as f:
    all_models = pickle.load(f)

# %%
import collections
assert(len([item for item, count in collections.Counter(all_models).items() if count > 1]) == 0)

# %%
cache_dir = os.path.expanduser("cache/")

def retrieve_and_cache(url,verbose=False,session=None):
    # pass in a requests.Session() object if you want to make many calls, keeping the connection open.
    # This gives you a 2x speedup.
    
    # This caching has a MAJOR FLAW: It does not check whether the page has been updated.
    # Once downloaded, it will keep the file forever. 
    # This is acceptable since this is to aid development when I don't want to repeatedly hit the 
    # server and wait for a download, but, this is NOT well-suited for scraping the site to check for updates.
    # I suggest deleting the cache folder before doing a big scrape
    #
    # We can also try out CacheControl https://cachecontrol.readthedocs.io/en/latest/
    
    start_time = time.time()
    if not os.path.exists(cache_dir):
        if verbose:
            print("Initializing cache directory")
        os.makedirs(cache_dir)
    filename = urllib.parse.quote(url, '')
    filepath = os.path.join(cache_dir, filename)
    if verbose:
        print("Checking cache for", filename)
    raw_html = ""

    if os.path.exists(filepath):
        if verbose:
            print("  Retrieving from cache")
        with open(filepath, 'r') as file:
            raw_html = file.read()
    else:
        if verbose:
            print("  Fetching and saving to cache")
        response = None
        if session:
            response = session.get(url)
        else:
            response = requests.get(url)
        
        raw_html = response.text
        with open(filepath, 'x') as file:
            file.write(raw_html)
    if verbose:
        print("  Took", time.time() - start_time,"seconds")
    return raw_html

def dedupe_list_preserving_order(items):
    return list(dict.fromkeys(items))

def parse_table_to_dict(text,url=None): # Parses the first Make-Model table we find on the page.
    soup = BeautifulSoup(text, 'lxml') # important to pip install lxml
    output = {}
    
    # Find the Table
    hook = soup.find_all(string=re.compile(".*Make Model.*"))
    if len(hook) == 0:
        return output
    if len(hook) > 1:
        print("Woah more than one table at",url)
    assert(len(hook)>=1)  # Assert we find at least one NavigatableString containing "Make Model"
    table = None
    for h in hook: # Let's find the first one that is inside a table. 
        if h.find_parent('table'):
            table = h.find_parent('table')
            break
    assert(table) # We assert we did find one
    rows = table.find_all('tr')
    assert(len(rows) > 1) # Assert we've found and parsed a table with many rows
    
    # Extract the key:value pairs
    for row in rows:
        cols = row.find_all('td')
        if len(cols) != 2:
            print("We found more than 2 columns, using only the first two, on page", url)
            continue
        assert(len(cols) == 2) # We expect two columns in each row, which we treat as a key:value pair
        key = cols[0].get_text().strip()
        value = cols[1].get_text().strip().replace("\t", "")
        output[key] = value
    return output

def decorate_table(table_dict, key_vals):
    return table_dict | key_vals

def get_mfct(name):
    for i, m in enumerate(mfct_urls):
        if m['mfct'] == name:
            return m
    return None
        
def clean_keys(table_dict,url=None):
    d = {}
    for k, v in table_dict.items():
        # Remove punctuation 
        k = k.translate(str.maketrans('', '', '!"#$%&\'()*+,-.:;<=>?@[\]^_`{|}~'))
        
        # Remove extraneous whitespace
        k = " ".join(k.split()).strip()
        
        # Ensure Title Case
        k = k.title()

        # Collapse certain special cases. DANGER, THIS WILL COLLIDE TABLE ENTRIES
        k = k.replace("Abs", "ABS")
        k = k.replace("Rear Wheels", "Rear Wheel")
        k = k.replace("Wheels Rear", "Rear Wheel")
        k = k.replace("Front Wheels", "Front Wheel")
        k = k.replace("Wheels Front", "Front Wheel")
        k = k.replace("Final Reduction Ratio", "Final Reduction")
        k = k.replace("Gear Ratios", "Gear Ratio")
        k = k.replace("Primary Reduction Ratio", "Primary Reduction")
        
        # Save the new key
        if k in d:
            # Combine entries if there's a colliding key. If no collision, we ignore.
            if d[k].strip() != v.strip():
                #print("Found colliding entries for key", k, "combining old value [",d[k],"] and new value [",v,"] for",url)
                d[k] = d[k] + " | " + v
        else:
            d[k] = v
                
        
    return d

def clean_vals(table_dict,url=None):
    d = {}
    for k, v in table_dict.items():
        # Remove extraneous whitespace
        v = " ".join(v.split()).strip()

        # Save the new key
        d[k] = v
        
    return d

def clean_model_table(table_dict,url=None):
    return clean_vals(clean_keys(table_dict,url=url),url=url)

# %%
def get_table_for_url(url):
    raw_html = retrieve_and_cache(url)
    table_dict = parse_table_to_dict(raw_html,url=url)
    table_dict_decorated = decorate_table(table_dict, {"Link":url})
    table_dict_decorated_cleaned = clean_model_table(table_dict_decorated,url=url)
    return table_dict_decorated_cleaned

# %%
def get_all_model_tables_for_mfct(mfct_name):
    m = get_mfct(mfct_name)
    tables = []
    for url in m['models']:
        table = get_table_for_url(url)
        tables.append(table)
    return tables

# %%
cleaned_tables = get_all_model_tables_for_mfct('Kawasaki')
# Out:
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/kawasaki/kawasaki_s3_400%2075.htm
# We found more than 2 columns, using only the first two, on page https://www.motorcyclespecs.co.za/model/kawasaki/kawasaki_s3_400%2075.htm
# Found colliding entries for key Ground Clearance combining old value [ 1435 mm / 56.5 in. ] and new value [ 125 mm / 4.9 in ] for https://www.motorcyclespecs.co.za/model/kawasaki/kawasaki_z1000r_17.htm
# Found colliding entries for key Ground Clearance combining old value [ 1435 mm / 56.5 in. ] and new value [ 125 mm / 4.9 in ] for https://www.motorcyclespecs.co.za/model/kawasaki/kawasaki_z1000r_19.html

# %%
import pandas as pd
df = pd.DataFrame(cleaned_tables)
df
df.to_csv('kawitest.csv')

# %%
mfct_urls
# Out:
# [{'mfct': 'AC Schnitzer',
#   'base_url': 'https://www.motorcyclespecs.co.za/bikes/AC_Schnitzer.html',
#   'all_mfct_urls': ['https://www.motorcyclespecs.co.za/bikes/AC_Schnitzer.html'],
#   'models': ['https://www.motorcyclespecs.co.za/model/AC%20Schnitzer/ac_schnitzer_f_650cs.htm',
#    'https://www.motorcyclespecs.co.za/model/AC%20Schnitzer/ac_schnitzer_F800R.htm',
#    'https://www.motorcyclespecs.co.za/model/AC%20Schnitzer/ac_schnitzer_800s_twinstar.htm',
#    'https://www.motorcyclespecs.co.za/model/AC%20Schnitzer/ac_schnitzer_hp2.htm',
#    'https://www.motorcyclespecs.co.za/model/AC%20Schnitzer/ac_schnitzer_k_1200rGT.htm',
#    'https://www.motorcyclespecs.co.za/model/AC%20Schnitzer/ac_schnitzer_k1200r.htm',
#    'https://www.motorcyclespecs.co.za/model/AC%20Schnitzer/ac_schnitzer_k_1200rs.htm',
#    'https://www.motorcyclespecs.co.za/model/AC%20Schnitzer/ac_schnitzer_k_1200s.htm',
#    'https://www.motorcyclespecs.co.za/model/AC%20Schnitzer/ac_schnitzer_k1300s.htm',
#    'https://www.motorcyclespecs.co.za/model/AC%20Schnitzer/ac_schnitzer_bmw_k1300r.htm',
#    'https://www.motorcyclespecs.co.za/model/AC%20Schnitzer/ac_schnitzer_k_1200r%20sport%2007.htm',
#    'https://www.motorcyclespecs.co.za/model/AC%20Schnitzer/ac_schnitzer_r_1100s.htm',
#    'https://www.motorcyclespecs.co.za/model/AC%20Schnitzer/ac_schnitzer_r_1150gs.htm',
#    'https://www.motorcyclespecs.co.za/model/AC%20Schnitzer/ac_schnitzer_r_1150r_rockster.htm',
#    'https://www.motorcyclespecs.co.za/model/AC%20Schnitzer/ac_schnitzer_r_1200c.htm',
#    'https://www.motorcyclespecs.co.za/model/AC%20Schnitzer/ac_schnitzer_r_1200gs.htm',
#    'https://www.motorcyclespecs.co.za/model/AC%20Schnitzer/ac-schnitzer-bmw-r1200rl%20.html',
#    'https://www.motorcyclespecs.co.za/model/AC%20Schnitzer/ac_schnitzer_r_1200rt.htm',
#    'https://www.motorcyclespecs.co.za/model/AC%20Schnitzer/ac_schnitzer_r_1200s.htm',
#    'https://www.motorcyclespecs.co.za/model/AC%20Schnitzer/ac_schnitzer_r_1200st.htm',
#    'https://www.motorcyclespecs.co.za/model/AC%20Schnitzer/ac-schnitzer-r-nine-t.html',
#    'https://www.motorcyclespecs.co.za/model/AC%20Schnitzer/ac_schnitzer_s_1000rr.htm'],
#   'df':                                   Make Model  Year  \
#   0                       AC Schnitzer F 650CS  2004
#   1                                        NaN   NaN
#   2   AC Schnitzer F800S Twinstar / Sprintstar  2006
#   3                           AC Schnitzer HP2  2007
#   4                      AC Schnitzer K 1200GT  2005
#   5                                        NaN   NaN
#   6                      AC Schnitzer K 1200RS  2005
#   7                       AC Schnitzer K 1200S  2005
#   8                                        NaN   NaN
#   9                                        NaN   NaN
#   10                AC Schnitzer K 1200R Sport  2007
#   11                      AC Schnitzer R 1100S  2004
#   12                     AC Schnitzer R 1150GS   NaN
#   13                     AC Schnitzer R 1150GS   NaN
#   14              AC Schnitzer R 1200C Classic   NaN
#   15                     AC Schnitzer R 1200GS   NaN
#   16             AC Schnitzer R 1200R Roadster  2006
#   17          AC Schnitzer R1200RT and R1200ST  2005
#   18           AC Schnitzer R 1200S Sprintstar  2006
#   19                     AC Schnitzer R 1200ST  2005
#   20                                       NaN   NaN
#   21                                       NaN   NaN
#
#                                                  Engine              Capacity  \
#   0   Single cylinder, 4-stroke, DOHC, 4 valves per ...   652 cc / 39.8 cu in
#   1                                                 NaN                   NaN
#   2   Parallel twin cylinder, 4-stroke, DOHC, 4 valv...   798 cc / 48.7 cu in
#   3   Four stroke, two cylinder horizontally opposed...  1170 cc / 71.4 cu in
#   4   Four stroke, horizontal in line four cylinder,...  1157 cc / 70.6 cu in
#   5                                                 NaN                   NaN
#   6   Four stroke, horizontal in line four cylinder,...  1171 cc / 71.5 cu in
#   7   Four stroke, transverse four cylinder, DOHC, 4...  1157 cc / 70.6 cu in
#   8                                                 NaN                   NaN
#   9                                                 NaN                   NaN
#   10  Four stroke, transverse four cylinder, DOHC, 4...  1157 cc / 70.6 cu in
#   11  Four stroke, two cylinder horizontally opposed...  1085 cc / 66.2 cu in
#   12  Four stroke, two cylinder horizontally opposed...  1130 cc / 69.0 cu in
#   13  Four stroke, two cylinder horizontally opposed...  1130 cc / 69.0 cu in
#   14  Four stroke, two cylinder horizontally opposed...  1170 cc / 71.4 cu in
#   15  Four stroke, two cylinder horizontally opposed...  1170 cc / 71.4 cu in
#   16  Four stroke, two cylinder horizontally opposed...  1170 cc / 71.4 cu in
#   17  Four stroke, two cylinder horizontally opposed...  1170 cc / 71.4 cu in
#   18  Four stroke, two cylinder horizontally opposed...  1170 cc / 71.4 cu in
#   19  Four stroke, two cylinder horizontally opposed...                  1170
#   20                                                NaN                   NaN
#   21                                                NaN                   NaN
#
#       Bore X Stroke Compression Ratio  Cooling System  \
#   0     100 x 83 mm            11.5:1   Liquid cooled
#   1             NaN               NaN             NaN
#   2    82 x 75.8 mm            12.0:1   Liquid cooled
#   3     101 x 73 mm            11.0:1  Air/oil cooled
#   4      79 x 59 mm            13.0:1   Liquid cooled
#   5             NaN               NaN             NaN
#   6    70.5 x 75 mm            11.5:1   Liquid cooled
#   7      79 X 59 mm            13.0:1   Liquid cooled
#   8             NaN               NaN             NaN
#   9             NaN               NaN             NaN
#   10     79 X 59 mm            13.0:1   Liquid cooled
#   11   99 x 70.5 mm            11.3:1  Air/oil cooled
#   12  101 x 70.5 mm            10.3:1  Air/oil cooled
#   13  101 x 70.5 mm            10.3:1  Air/oil cooled
#   14    101 x 73 mm            10.0:1  Air/oil cooled
#   15    101 x 73 mm            11.0:1  Air/oil cooled
#   16    101 x 73 mm            12.0:1             NaN
#   17    101 x 73 mm            12.0:1             NaN
#   18    101 x 73 mm            12.5:1             NaN
#   19    101 x 73 mm            11.0:1             NaN
#   20            NaN               NaN             NaN
#   21            NaN               NaN             NaN
#
#                                           Induction  \
#   0                                  Fuel induction
#   1                                             NaN
#   2                     Electronic intake injection
#   3   Fuel Injection, 47mm throttle butterfly BMS-K
#   4                             BMSK fuel Injection
#   5                                             NaN
#   6                                  Fuel injection
#   7                             BMSK fuel Injection
#   8                                             NaN
#   9                                             NaN
#   10                                      Injection
#   11                           Bosch fuel injection
#   12                                 Fuel injection
#   13                                 Fuel injection
#   14               Electronic intake pipe injection
#   15                                          BMS-K
#   16     Electronic intake manifold injection BMS-K
#   17     Electronic intake manifold injection BMS-K
#   18        Fuel injection, 52mm throttle butterfly
#   19                   BMW engine management, BMS-K
#   20                                            NaN
#   21                                            NaN
#
#                                                Ignition  Starting  ...  \
#   0   Electronic ignition integrated with fuel manag...  Electric  ...
#   1                                                 NaN       NaN  ...
#   2                                                 NaN  Electric  ...
#   3                                               BMS-K  Electric  ...
#   4                                                 NaN  Electric  ...
#   5                                                 NaN       NaN  ...
#   6                      Ignition MA 2.4 Bosch Motronic  Electric  ...
#   7                                          Electronic  Electric  ...
#   8                                                 NaN       NaN  ...
#   9                                                 NaN       NaN  ...
#   10                                         Electronic  Electric  ...
#   11                  Bosch Electronic Two Spark System  Electric  ...
#   12          Electronic ignition MA 2.2 Bosch Motronic  Electric  ...
#   13          Electronic ignition MA 2.2 Bosch Motronic  Electric  ...
#   14                                                NaN  Electric  ...
#   15                                                NaN  Electric  ...
#   16                                                NaN  Electric  ...
#   17                                                NaN  Electric  ...
#   18                                                NaN  Electric  ...
#   19                                                NaN       NaN  ...
#   20                                                NaN       NaN  ...
#   21                                                NaN       NaN  ...
#
#              Dryweight Front Wheel        Rear Wheel           Overview  \
#   0                NaN         NaN               NaN                NaN
#   1                NaN         NaN               NaN                NaN
#   2                NaN         NaN               NaN                NaN
#   3                NaN         NaN               NaN                NaN
#   4   249 kg / 549 lbs         NaN               NaN                NaN
#   5                NaN         NaN               NaN                NaN
#   6                NaN         NaN               NaN                NaN
#   7                NaN         NaN               NaN                NaN
#   8                NaN         NaN               NaN                NaN
#   9                NaN         NaN               NaN                NaN
#   10               NaN         NaN               NaN                NaN
#   11               NaN   3.5J x 17  5.5 or 6.0J x 17  Ultimate Car Page
#   12               NaN    3.5 x 17          6.0 x 17                NaN
#   13               NaN    3.5 x 17          6.0 x 17                NaN
#   14               NaN         NaN               NaN                NaN
#   15               NaN    3.5 x 17          5.5 x 17                NaN
#   16               NaN         NaN               NaN                NaN
#   17               NaN    3.5 x 17          5.5 x 17                NaN
#   18               NaN         NaN               NaN                NaN
#   19                           NaN               NaN                NaN
#   20               NaN         NaN               NaN                NaN
#   21               NaN         NaN               NaN                NaN
#
#      Standing 0 100 Km/H / 62 Mph Standing 0 140 Km/H / 87 Mph  \
#   0                           NaN                          NaN
#   1                           NaN                          NaN
#   2                           NaN                          NaN
#   3                           NaN                          NaN
#   4                           NaN                          NaN
#   5                           NaN                          NaN
#   6                           NaN                          NaN
#   7                           NaN                          NaN
#   8                           NaN                          NaN
#   9                           NaN                          NaN
#   10                          NaN                          NaN
#   11                          NaN                          NaN
#   12                          NaN                          NaN
#   13                          NaN                          NaN
#   14                          NaN                          NaN
#   15                          NaN                          NaN
#   16                      3.4 sec                      6.4 sec
#   17                          NaN                          NaN
#   18                          NaN                          NaN
#   19                          NaN                          NaN
#   20                          NaN                          NaN
#   21                          NaN                          NaN
#
#      Standing 0 200 Km/H / 124 Mph Acceleration 60140 Km/H / 3787 Mph  \
#   0                            NaN                                NaN
#   1                            NaN                                NaN
#   2                            NaN                                NaN
#   3                            NaN                                NaN
#   4                            NaN                                NaN
#   5                            NaN                                NaN
#   6                            NaN                                NaN
#   7                            NaN                                NaN
#   8                            NaN                                NaN
#   9                            NaN                                NaN
#   10                           NaN                                NaN
#   11                           NaN                                NaN
#   12                           NaN                                NaN
#   13                           NaN                                NaN
#   14                           NaN                                NaN
#   15                           NaN                                NaN
#   16                      15,0 sec                            7,9 sec
#   17                           NaN                                NaN
#   18                           NaN                                NaN
#   19                           NaN                                NaN
#   20                           NaN                                NaN
#   21                           NaN                                NaN
#
#                        Ignition / Starting Transmission / Drive
#   0                                    NaN                  NaN
#   1                                    NaN                  NaN
#   2                                    NaN                  NaN
#   3                                    NaN                  NaN
#   4                                    NaN                  NaN
#   5                                    NaN                  NaN
#   6                                    NaN                  NaN
#   7                                    NaN                  NaN
#   8                                    NaN                  NaN
#   9                                    NaN                  NaN
#   10                                   NaN                  NaN
#   11                                   NaN                  NaN
#   12                                   NaN                  NaN
#   13                                   NaN                  NaN
#   14                                   NaN                  NaN
#   15                                   NaN                  NaN
#   16                                   NaN                  NaN
#   17                                   NaN                  NaN
#   18                                   NaN                  NaN
#   19  Digital engine management / electric      6 Speed / shaft
#   20                                   NaN                  NaN
#   21                                   NaN                  NaN
#
#   [22 rows x 45 columns]},
#  {'mfct': 'Adler',
#   'base_url': 'https://www.motorcyclespecs.co.za/bikes/Adler.html',
#   'all_mfct_urls': ['https://www.motorcyclespecs.co.za/bikes/Adler.html'],
#   'models': ['https://www.motorcyclespecs.co.za/model/Adler/adler-1902.html',
#    'https://www.motorcyclespecs.co.za/model/Adler/adler-favorit.html',
#    'https://www.motorcyclespecs.co.za/model/Adler/Adler%20ISDT.htm',
#    'https://www.motorcyclespecs.co.za/model/Adler/adler-junior-m100.html',
#    'https://www.motorcyclespecs.co.za/model/Adler/adler-m100.html',
#    'https://www.motorcyclespecs.co.za/model/Adler/adler-m125.html',
#    'https://www.motorcyclespecs.co.za/model/Adler/adler-mb150.html',
#    'https://www.motorcyclespecs.co.za/model/Adler/adler-mb200.html',
#    'https://www.motorcyclespecs.co.za/model/Adler/adler-mb250rs.html',
#    'https://www.motorcyclespecs.co.za/model/Adler/adler-mb250.html',
#    'https://www.motorcyclespecs.co.za/model/Adler/adler-mb250s.html'],
#   'df':            Make Model       Year  \
#   0          Adler 1902       1902
#   1       Adler Favorit  1957 - 60
#   2          Adler ISDT       1957
#   3   Adler Junior M100       1955
#   4         Adler M 100  1949 - 56
#   5         Adler M 125  1952 - 56
#   6        Adler MB 150  1953 - 54
#   7         Adler M 200       1952
#   8     Adler MB 250 RS       1953
#   9        Adler MB 250       1955
#   10      Adler MB 250S       1955
#
#                                                 Colours  \
#   0            Black/Green striping, Black/red striping
#   1                                   Black, Blue-Green
#   2                                          Black, Red
#   3                           Light Blue-Green metallic
#   4   Black with gold striping / Red with gold striping
#   5                                               Black
#   6                           Black with gold pinstripe
#   7                                                 NaN
#   8                                                 NaN
#   9                                                 NaN
#   10                                                NaN
#
#                                            Source  \
#   0   Wikipedia, Manxnorton.com, Moto-catalog.org
#   1                                           NaN
#   2                                           NaN
#   3                                           NaN
#   4                                           NaN
#   5                                           NaN
#   6                                           NaN
#   7                                           NaN
#   8                                           NaN
#   9                                           NaN
#   10                                          NaN
#
#                                                    Link  \
#   0   https://www.motorcyclespecs.co.za/model/Adler/...
#   1   https://www.motorcyclespecs.co.za/model/Adler/...
#   2   https://www.motorcyclespecs.co.za/model/Adler/...
#   3   https://www.motorcyclespecs.co.za/model/Adler/...
#   4   https://www.motorcyclespecs.co.za/model/Adler/...
#   5   https://www.motorcyclespecs.co.za/model/Adler/...
#   6   https://www.motorcyclespecs.co.za/model/Adler/...
#   7   https://www.motorcyclespecs.co.za/model/Adler/...
#   8   https://www.motorcyclespecs.co.za/model/Adler/...
#   9   https://www.motorcyclespecs.co.za/model/Adler/...
#   10  https://www.motorcyclespecs.co.za/model/Adler/...
#
#                                               Engine               Capacity  \
#   0                                              NaN                    NaN
#   1                     2 cylinder, 2 stroke, inline  247 cc / 15.1 cub in.
#   2       2 cylinder, 2 stroke, flat-crowned pistons  247 cc / 15.1 cub in.
#   3                             1 cylinder, 2 stroke      98 cc / 6 cub in.
#   4                             1 cylinder, 2 stroke      98 cc / 6 cub in.
#   5                             1 cylinder, 2 stroke  123 cc / 7.51 cub in.
#   6                        Single cylinder, 2 stroke     147 cc / 9 cub in.
#   7   Air cooled, two stroke, parallel twin cylinder                    195
#   8       2 cylinder, 2 stroke, flat-crowned pistons  247 cc / 15.1 cub in.
#   9       2 cylinder, 2 stroke, flat-crowned pistons  247 cc / 15.1 cub in.
#   10      2 cylinder, 2 stroke, flat-crowned pistons  247 cc / 15.1 cub in.
#
#      Bore X Stroke     Cooling          Lubrication  ...   Front Wheel  \
#   0            NaN         NaN                  NaN  ...           NaN
#   1     54 x 54 mm  Air cooled  Petrol oil mix 25:1  ...           NaN
#   2     54 x 54 mm  Air cooled  Petrol oil mix 25:1  ...           NaN
#   3     50 x 50 mm  Air cooled  Petrol oil mix 25:1  ...  3.00 x 14 in
#   4     50 x 50 mm  Air cooled  Petrol oil mix 25:1  ...           NaN
#   5     54 x 54 mm  Air cooled  Petrol oil mix 25:1  ...           NaN
#   6     59 x 54 mm  Air cooled  Petrol oil mix 25:1  ...           NaN
#   7     48 x 54 mm         NaN                  NaN  ...           NaN
#   8     54 x 54 mm  Air cooled  Petrol oil mix 25:1  ...           NaN
#   9     54 x 54 mm  Air cooled  Petrol oil mix 25:1  ...           NaN
#   10    54 x 54 mm  Air cooled  Petrol oil mix 25:1  ...           NaN
#
#              Brake    Production   Induction Ignition / Starting  \
#   0            NaN           NaN         NaN                 NaN
#   1            NaN           NaN         NaN                 NaN
#   2            NaN           NaN         NaN                 NaN
#   3   Drum, 125 mm           NaN         NaN                 NaN
#   4   Drum, 125 mm  35 000 units         NaN                 NaN
#   5            NaN         5 500         NaN                 NaN
#   6            NaN   2 500 units         NaN                 NaN
#   7            NaN           NaN  Carburetor       6 volt / kick
#   8            NaN           NaN         NaN                 NaN
#   9            NaN           NaN         NaN                 NaN
#   10           NaN           NaN         NaN                 NaN
#
#      Transmission / Drive Front Brakes Rear Brakes Front Tyre Rear Tyre
#   0                   NaN          NaN         NaN        NaN       NaN
#   1                   NaN          NaN         NaN        NaN       NaN
#   2                   NaN          NaN         NaN        NaN       NaN
#   3                   NaN          NaN         NaN        NaN       NaN
#   4                   NaN          NaN         NaN        NaN       NaN
#   5                   NaN          NaN         NaN        NaN       NaN
#   6                   NaN          NaN         NaN        NaN       NaN
#   7       4 Speed / chain   150mm Drum  150mm Drum   3,.5 -16  3,.5 -16
#   8                   NaN          NaN         NaN        NaN       NaN
#   9                   NaN          NaN         NaN        NaN       NaN
#   10                  NaN          NaN         NaN        NaN       NaN
#
#   [11 rows x 45 columns]},
#  {'mfct': 'AJP',
#   'base_url': 'https://www.motorcyclespecs.co.za/bikes/AJP.htm',
#   'all_mfct_urls': ['https://www.motorcyclespecs.co.za/bikes/AJP.htm'],
#   'models': ['https://www.motorcyclespecs.co.za/model/AJP/AJP%20GALP%2050%20R.htm',
#    'https://www.motorcyclespecs.co.za/model/AJP/AJP%20PR3125%20Series%2014.htm',
#    'https://www.motorcyclespecs.co.za/model/AJP/AJP%20PR3%20200%20Enduro%20Pro%2014.htm',
#    'https://www.motorcyclespecs.co.za/model/AJP/AJP%20PR4%20125%20Enduro%2001.htm',
#    'https://www.motorcyclespecs.co.za/model/AJP/AJP%20PR4%20125%20Enduro%202004.htm',
#    'https://www.motorcyclespecs.co.za/model/AJP/AJP%20PR4%20125%20Enduro%2007.htm',
#    'https://www.motorcyclespecs.co.za/model/AJP/AJP%20PR4%20125%20Enduro%20Pro%2014.htm',
#    'https://www.motorcyclespecs.co.za/model/AJP/AJP%20PR4%20200%20Enduro%2004.htm',
#    'https://www.motorcyclespecs.co.za/model/AJP/AJP%20PR4%20200%20Enduro%2007.htm',
#    'https://www.motorcyclespecs.co.za/model/AJP/AJP%20PR4%20200%20Enduro%20Pro%2014.htm',
#    'https://www.motorcyclespecs.co.za/model/AJP/AJP%20PR4%20240%20Enduro%20Pro%2014.htm',
#    'https://www.motorcyclespecs.co.za/model/AJP/AJP%20PR5%20Series%2014.htm',
#    'https://www.motorcyclespecs.co.za/model/AJP/AJP%20PR7%20660%20Adventure%2015.htm',
#    'https://www.motorcyclespecs.co.za/model/AJP/AJP_PR7.htm',
#    'https://www.motorcyclespecs.co.za/model/AJP/AJP_PR7_adventure_19.html'],
#   'df':                                        Make Model       Year  \
#   0                                   AJP Galp 50 R       2005
#   1      AJP PR3 125 Trail, Enduro (Pro), Supermoto  2009 - 14
#   2               AJP PR3 200 Enduro Pro, Supermoto  2009 - 14
#   3                   AJP PR4 125 Enduro, Supermoto  2001 - 02
#   4                   AJP PR4 125 Enduro, Supermoto  2003 - 06
#   5                   AJP PR4 125 Enduro, Supermoto  2007 - 08
#   6             AJP PR4 125 Enduro (Pro), Supermoto       2014
#   7                   AJP PR4 200 Enduro, Supermoto  2004 - 06
#   8                   AJP PR4 200 Enduro, Supermoto  2007 - 09
#   9               AJP PR4 200 Enduro Pro, Supermoto  2009 - 14
#   10   AJP PR4 240 Enduro (Pro), Supermoto, Extreme       2014
#   11  AJP PR5 250 Enduro, Trail, Supermoto, Extreme       2014
#   12                          AJP PR7 660 Adventure       2016
#   13                              AJP PR7 Adventure       2016
#   14                              AJP PR7 Adventure     2019 -
#
#                                         Engine                Capacity  \
#   0                  Single cylinder, 2-stroke   49.9 cc / 3.04 cub in
#   1         Single cylinder, 4-stroke, 2-valve     124 cc / 7.6 cub in
#   2         Single cylinder, 4-stroke, 2-valve    198 cc / 12.1 cub in
#   3         Single cylinder, 4-stroke, 2-valve     124 cc / 7.6 cub in
#   4         Single cylinder, 4-stroke, 2-valve     124 cc / 7.6 cub in
#   5         Single cylinder, 4-stroke, 2-valve     124 cc / 7.6 cub in
#   6         Single cylinder, 4-stroke, 2-valve     124 cc / 7.6 cub in
#   7   Single cylinder, 4-stroke, 2-valve, SOHC    198 cc / 12.1 cub in
#   8   Single cylinder, 4-stroke, 2-valve, SOHC    198 cc / 12.1 cub in
#   9         Single cylinder, 4-stroke, 2-valve    198 cc / 12.1 cub in
#   10        Single cylinder, 4-stroke, 2-valve    233 cc / 14.2 cub in
#   11   Single cylinder, 4-stroke, 4-valve, OHC    249 cc / 15.2 cub in
#   12                 Single cylinder, 4-stroke  659.7 cc / 40.3 cub in
#   13                Single cylinder, SWM, DOHC   600.3 cc / 36.6 cu in
#   14       Single cylinder, SWM, DOHC, 4 valve   600.3 cc / 36.6 cu in
#
#        Bore X Stroke  Cooling System       Exhaust  \
#   0     40 x 39.7 mm          Liquid      1-into-1
#   1   56.5 x 49.5 mm  Air/oil cooled      1-into-1
#   2       69 x 53 mm  Air/oil cooled      1-into-1
#   3   56.5 x 49.5 mm  Air/oil cooled      1-into-1
#   4   56.5 x 49.5 mm  Air/oil cooled      1-into-1
#   5   56.5 x 49.5 mm  Air/oil cooled      1-into-1
#   6   56.5 x 49.5 mm  Air/oil cooled      1-into-1
#   7   68.8 x 53.3 mm  Air/oil cooled      1-into-1
#   8   68.8 x 53.3 mm  Air/oil cooled      1-into-1
#   9       69 x 53 mm  Air/oil cooled      1-into-1
#   10    69 x 62.5 mm  Air/oil cooled      1-into-1
#   11    77 x 53.6 mm   Liquid cooled      1-into-1
#   12             NaN   Liquid cooled      2-into-1
#   13   100 x 76.4 mm   Liquid cooled  Two into one
#   14   100 x 76.4 mm   Liquid cooled  Two into one
#
#                                               Induction    Ignition  \
#   0                                          Carburetor         CDI
#   1                             Walbro 30 mm carburetor         NaN
#   2                                 PZ 30 mm carburetor         NaN
#   3                                    26 mm carburetor         CDI
#   4                                    26 mm carburetor         CDI
#   5                                    26 mm carburetor         CDI
#   6                             Walbro 30 mm carburetor         NaN
#   7                             Walbro 30 mm carburetor         CDI
#   8                             Walbro 30 mm carburetor         CDI
#   9                                 PZ 30 mm carburetor         NaN
#   10                                PZ 30 mm carburetor         NaN
#   11                        Delphi fuel inection system         NaN
#   12  Electronic fuel injection, 44 mm Mikuni thrott...         NaN
#   13      Electronic fuel injection, 45mm throttle body  Electronic
#   14                Delphi fuel injection system Ø45 mm  Electronic
#
#              Starting  ...                                         Dimensions  \
#   0   Electric + kick  ...                                                NaN
#   1   Electric + kick  ...                                                NaN
#   2   Electric + kick  ...                                                NaN
#   3   Electric + kick  ...  Length: Enduro 2135 mm / 84.1 in Length: Super...
#   4   Electric + kick  ...  Length: Enduro 2135 mm / 84.1 in Length: Super...
#   5   Electric + kick  ...  Length: Enduro 2135 mm / 84.1 in Length: Super...
#   6   Electric + kick  ...                                                NaN
#   7   Electric + kick  ...                          Length: 2136 mm / 84.1 in
#   8   Electric + kick  ...                          Length: 2136 mm / 84.1 in
#   9   Electric + kick  ...                                                NaN
#   10  Electric + kick  ...                                                NaN
#   11         Electric  ...                                                NaN
#   12         Electric  ...                                                NaN
#   13         Electric  ...                                                NaN
#   14         Electric  ...                                                NaN
#
#                Review         Tank Range  Tank Range Approx   Rake  \
#   0               NaN                NaN                NaN    NaN
#   1               NaN                NaN                NaN    NaN
#   2               NaN                NaN                NaN    NaN
#   3               NaN                NaN                NaN    NaN
#   4               NaN                NaN                NaN    NaN
#   5               NaN                NaN                NaN    NaN
#   6   Motorcycle News                NaN                NaN    NaN
#   7               NaN                NaN                NaN    NaN
#   8               NaN                NaN                NaN    NaN
#   9               NaN                NaN                NaN    NaN
#   10              NaN  145 km / 90 miles                NaN    NaN
#   11              NaN                NaN  129 km / 80 miles    NaN
#   12              NaN                NaN                NaN  26.5°
#   13              NaN                NaN                NaN    NaN
#   14              NaN                NaN                NaN    NaN
#
#         Dry Weight Est Lubrication Compression Ratio                Clutch  \
#   0                NaN         NaN               NaN                   NaN
#   1                NaN         NaN               NaN                   NaN
#   2                NaN         NaN               NaN                   NaN
#   3                NaN         NaN               NaN                   NaN
#   4                NaN         NaN               NaN                   NaN
#   5                NaN         NaN               NaN                   NaN
#   6                NaN         NaN               NaN                   NaN
#   7                NaN         NaN               NaN                   NaN
#   8                NaN         NaN               NaN                   NaN
#   9                NaN         NaN               NaN                   NaN
#   10               NaN         NaN               NaN                   NaN
#   11               NaN         NaN               NaN                   NaN
#   12  155 kg / 342 lbs         NaN               NaN                   NaN
#   13               NaN    Wet sump            12.4:1  Oil bath, multi disc
#   14               NaN    Wet sump            12.4:1  Oil bath, multi disc
#
#             Wet Weight
#   0                NaN
#   1                NaN
#   2                NaN
#   3                NaN
#   4                NaN
#   5                NaN
#   6                NaN
#   7                NaN
#   8                NaN
#   9                NaN
#   10               NaN
#   11               NaN
#   12               NaN
#   13  165 kg / 364 lbs
#   14  165 kg / 364 lbs
#
#   [15 rows x 44 columns]},
#  {'mfct': 'AJS',
#   'base_url': 'https://www.motorcyclespecs.co.za/bikes/AJS.htm',
#   'all_mfct_urls': ['https://www.motorcyclespecs.co.za/bikes/AJS.htm'],
#   'models': ['https://www.motorcyclespecs.co.za/model/AJS/AJS%20Collage.htm',
#    'https://www.motorcyclespecs.co.za/model/AJS/AJS%20Cadwell%20125.htm',
#    'https://www.motorcyclespecs.co.za/model/AJS/ajs_7r.htm',
#    'https://www.motorcyclespecs.co.za/model/AJS/AJS%20R7%20Track%20Racer.htm',
#    'https://www.motorcyclespecs.co.za/model/AJS/AJS%20Bobber125%202012.htm',
#    'https://www.motorcyclespecs.co.za/model/AJS/AJS%20Daytona%20125%202012.htm',
#    'https://www.motorcyclespecs.co.za/model/AJS/AJS%20DD125E%20Mk3%202012.htm',
#    'https://www.motorcyclespecs.co.za/model/AJS/AJS%20E95%20Porcupine%2054.htm',
#    'https://www.motorcyclespecs.co.za/model/AJS/AJS%20Eco2%20125%202012.htm',
#    'https://www.motorcyclespecs.co.za/model/AJS/AJS%20EOS%20125%202012.htm',
#    'https://www.motorcyclespecs.co.za/model/AJS/AJS%20H6%20Big%20Port%2027.htm',
#    'https://www.motorcyclespecs.co.za/model/AJS/AJS%20JSM%20Motard%202012.htm',
#    'https://www.motorcyclespecs.co.za/model/AJS/AJS%20Model%208%20350.htm',
#    'https://www.motorcyclespecs.co.za/model/AJS/AJS%20Model%2014%20250.htm',
#    'https://www.motorcyclespecs.co.za/model/AJS/ajs_model%2016.htm',
#    'https://www.motorcyclespecs.co.za/model/AJS/ajs_185_500cc.htm',
#    'https://www.motorcyclespecs.co.za/model/AJS/ajs_model%2020%2047.htm',
#    'https://www.motorcyclespecs.co.za/model/AJS/ajs_model_30.htm',
#    'https://www.motorcyclespecs.co.za/model/AJS/ajs_31csr_650_hurricane.htm',
#    'https://www.motorcyclespecs.co.za/model/AJS/AJS%20Model%20E1%201925.htm',
#    'https://www.motorcyclespecs.co.za/model/AJS/AJS%20NAC%2012%202012.htm',
#    'https://www.motorcyclespecs.co.za/model/AJS/AJS%20R7%202012.htm',
#    'https://www.motorcyclespecs.co.za/model/AJS/AJS%20Silver%20Streak%20500.htm',
#    'https://www.motorcyclespecs.co.za/model/AJS/Tempest%20Roadster%20125.htm',
#    'https://www.motorcyclespecs.co.za/model/AJS/ajs_y4_motocross_70.html',
#    'https://www.motorcyclespecs.co.za/model/AJS/ajs_y51_motocross_72.html',
#    'https://www.motorcyclespecs.co.za/model/Racers/ajs_350_big_port_1923.htm',
#    'https://www.motorcyclespecs.co.za/model/Racers/ajs_500_supercharged_v4.htm',
#    'https://www.motorcyclespecs.co.za/model/Racers/ajs_mcintyre_special.htm',
#    'https://www.motorcyclespecs.co.za/model/Racers/ajs_porqupine.html',
#    'https://www.motorcyclespecs.co.za/model/Racers/ajs_r7_1938.htm',
#    'https://www.motorcyclespecs.co.za/model/Racers/ajs_7r_racer_boy_1957.htm'],
#   'df':                                                  Link  \
#   0   https://www.motorcyclespecs.co.za/model/AJS/AJ...
#   1   https://www.motorcyclespecs.co.za/model/AJS/AJ...
#   2   https://www.motorcyclespecs.co.za/model/AJS/aj...
#   3   https://www.motorcyclespecs.co.za/model/AJS/AJ...
#   4   https://www.motorcyclespecs.co.za/model/AJS/AJ...
#   5   https://www.motorcyclespecs.co.za/model/AJS/AJ...
#   6   https://www.motorcyclespecs.co.za/model/AJS/AJ...
#   7   https://www.motorcyclespecs.co.za/model/AJS/AJ...
#   8   https://www.motorcyclespecs.co.za/model/AJS/AJ...
#   9   https://www.motorcyclespecs.co.za/model/AJS/AJ...
#   10  https://www.motorcyclespecs.co.za/model/AJS/AJ...
#   11  https://www.motorcyclespecs.co.za/model/AJS/AJ...
#   12  https://www.motorcyclespecs.co.za/model/AJS/AJ...
#   13  https://www.motorcyclespecs.co.za/model/AJS/AJ...
#   14  https://www.motorcyclespecs.co.za/model/AJS/aj...
#   15  https://www.motorcyclespecs.co.za/model/AJS/aj...
#   16  https://www.motorcyclespecs.co.za/model/AJS/aj...
#   17  https://www.motorcyclespecs.co.za/model/AJS/aj...
#   18  https://www.motorcyclespecs.co.za/model/AJS/aj...
#   19  https://www.motorcyclespecs.co.za/model/AJS/AJ...
#   20  https://www.motorcyclespecs.co.za/model/AJS/AJ...
#   21  https://www.motorcyclespecs.co.za/model/AJS/AJ...
#   22  https://www.motorcyclespecs.co.za/model/AJS/AJ...
#   23  https://www.motorcyclespecs.co.za/model/AJS/Te...
#   24  https://www.motorcyclespecs.co.za/model/AJS/aj...
#   25  https://www.motorcyclespecs.co.za/model/AJS/aj...
#   26  https://www.motorcyclespecs.co.za/model/Racers...
#   27  https://www.motorcyclespecs.co.za/model/Racers...
#   28  https://www.motorcyclespecs.co.za/model/Racers...
#   29  https://www.motorcyclespecs.co.za/model/Racers...
#   30  https://www.motorcyclespecs.co.za/model/Racers...
#   31  https://www.motorcyclespecs.co.za/model/Racers...
#
#                                  Make Model       Year  \
#   0                                     NaN        NaN
#   1              AJS Cadwell 125 Café Racer       2016
#   2                                     NaN        NaN
#   3                      AJS R7 Track Racer       1930
#   4                          AJS Bobber 125  2012 - 14
#   5                         AJS Daytona 125  2012 - 14
#   6                          AJS DD125E Mk3  2012 - 14
#   7                       AJS E95 Porcupine       1954
#   8                AJS Eco2 125 (JS125 E-2)  2012 - 14
#   9                         AJS EOS 125 Mk2  2012 - 14
#   10                    AJS H6 Big Port 350       1927
#   11                         AJS JSM Motard  2012 - 14
#   12                        AJS Model 8 350  1960 - 62
#   13  AJS Model 14 250 / 250CSR / Scrambler  1958 - 66
#   14                       AJS Model 16 350    1950-66
#   15    AJS Model 18 500 (S, CS, Statesman)  1945 - 66
#   16                       AJS Model 20 500  1948 - 61
#   17                       AJS Model 30 600       1956
#   18                       AJS Model 31 650  1957 - 66
#   19                      AJS Model E1 / E2       1925
#   20                             AJS NAC 12  2012 - 14
#   21                                 AJS R7  2012 - 14
#   22                  AJS Silver Streak 500       1938
#   23               AJS Tempest Roadster 125     2017 -
#   24                                    NaN        NaN
#   25                                    NaN        NaN
#   26                                    NaN        NaN
#   27                                    NaN        NaN
#   28                                    NaN        NaN
#   29                                    NaN        NaN
#   30                                    NaN        NaN
#   31                                    NaN        NaN
#
#                                                  Engine               Capacity  \
#   0                                                 NaN                    NaN
#   1                      Single cylinder, 4-stroke, OHC     124 cc / 7.6 cu in
#   2                                                 NaN                    NaN
#   3                                Single cylinder, OHC   350 cc / 21.4 cub in
#   4                             Twin cylinder, 4-stroke    124 cc / 7.6 cub in
#   5                             Twin cylinder, 4-stroke    124 cc / 7.6 cub in
#   6                             Twin cylinder, 4-stroke    124 cc / 7.6 cub in
#   7   Twin cylinder inclined at 45°, aluminium alloy...       497 cc / 30.3 in
#   8   Single cylinder, 4-stroke, OHC with balance shaft    124 cc / 7.6 cub in
#   9                             Twin cylinder, 4-stroke    124 cc / 7.6 cub in
#   10                     Single cylinder, 4-stroke, OHV    349 cc / 21.3 cu in
#   11                          2-Stroke, single cylinder   49.3 cc / 3.0 cub in
#   12            Single cylinder, 4 stroke, OHV, 2-valve   347 cc / 21.2 cub in
#   13                     Single cylinder, 4-stroke, OHV  248.5 cc / 15.2 cu in
#   14  Air cooled, single cylinder, 2 valve per cylinder    347 cc / 21.2 cu in
#   15  Single cylinder, 2 valve per cylinder, pushrod...     498 c / 30.4 cu in
#   16  Four stroke, parallel twin cylinder, OHV. 2 va...    498 cc / 30.4 cu in
#   17  Four stroke, pushrod parallel twin, OHV, 2 val...    593 cc / 36.2 cu in
#   18  Four stroke, pushrod parallel twin, OHV, 2 val...    646 cc / 39.4 cu in
#   19  V-twin, side valve, detachable head, aluminium...   799 cc / 48.8 cub in
#   20                            Twin cylinder, 4 stroke    124 cc / 7.6 cub in
#   21                     Single cylinder, 4 stroke, OHV    124 cc / 7.6 cub in
#   22  Single cylinder, single port, push-rod OHV wit...    498 cc / 30.4 cu in
#   23                  Single cylinder, YB 4-stroke, OHC     124 cc / 7.6 cu in
#   24                                                NaN                    NaN
#   25                                                NaN                    NaN
#   26                                                NaN                    NaN
#   27                                                NaN                    NaN
#   28                                                NaN                    NaN
#   29                                                NaN                    NaN
#   30                                                NaN                    NaN
#   31                                                NaN                    NaN
#
#          Bore X Stroke Cooling System           Starting  \
#   0                NaN            NaN                NaN
#   1         54 x 54 mm     Air cooled  Electric and kick
#   2                NaN            NaN                NaN
#   3                NaN     Air cooled                NaN
#   4         44 x 40 mm  Liquid cooled           Electric
#   5         44 x 40 mm  Liquid cooled           Electric
#   6         44 x 40 mm     Air cooled           Electric
#   7       68 x 68.5 mm     Air cooled                NaN
#   8         54 x 54 mm            NaN    Electric & Kick
#   9         44 x 40 mm  Liquid cooled           Electric
#   10        74 x 81 mm     Air cooled               Kick
#   11               NaN  Liquid cooled           Electric
#   12      72 x 85.5 mm     Air cooled               Kick
#   13  69.85 / 64.84 mm     Air cooled               Kick
#   14        69 × 93 mm            NaN               Kick
#   15      82.5 x 93 mm     Air cooled               Kick
#   16      66 x 72.8 mm     Air cooled               Kick
#   17      72 x 72.8 mm     Air cooled               Kick
#   18      72 x 79.3 mm     Air cooled               Kick
#   19        74 x 93 mm     Air cooled               Kick
#   20        44 x 40 mm  Liquid cooled           Electric
#   21    56.5 x 49.6 mm  Liquid cooled           Electric
#   22      82.5 x 93 mm     Air cooled               Kick
#   23        54 x 54 mm     Air cooled  Electric and kick
#   24               NaN            NaN                NaN
#   25               NaN            NaN                NaN
#   26               NaN            NaN                NaN
#   27               NaN            NaN                NaN
#   28               NaN            NaN                NaN
#   29               NaN            NaN                NaN
#   30               NaN            NaN                NaN
#   31               NaN            NaN                NaN
#
#                           Max Power             Transmission  ...  Drive  \
#   0                             NaN                      NaN  ...    NaN
#   1      7.1 kW / 9.5 hp @ 8500 rpm                  5-Speed  ...    NaN
#   2                             NaN                      NaN  ...    NaN
#   3                             NaN      Close ratio gearbox  ...    NaN
#   4         8 kW / 11 hp @ 9500 rpm                  5-Speed  ...    NaN
#   5         8 kW / 11 hp @ 9500 rpm                  5-Speed  ...    NaN
#   6                    8 kW / 11 hp                  5-Speed  ...    NaN
#   7        41 kW / 55 hp @ 7600 rpm     4-Speed, close ratio  ...    NaN
#   8     7.5 kW / 10.1 hp @ 8000 rpm                  5-Speed  ...    NaN
#   9         8 kW / 11 hp @ 9500 rpm                  5-Speed  ...    NaN
#   10               2.0 kW / 2.75 hp    3-Speed, countershaft  ...    NaN
#   11   3.5 kW / 10.1 hp @ 6 800 rpm                  6-Speed  ...    NaN
#   12       15.4 kW / 20.9 hp @ 6250                  4-Speed  ...    NaN
#   13                            NaN                  4-Speed  ...    NaN
#   14  13.2 kW / 17.95 hp @ 5750 rpm                  4 Speed  ...  Chain
#   15     20.9 kW / 28 hp @ 5600 rpm  4 Speed, Burman gearbox  ...  Chain
#   16                21.6 kW / 29 hp                  4 Speed  ...    NaN
#   17      24.6 kW / 33 hp @ 6800rpm                  4 Speed  ...  Chain
#   18     31,4 kW / 43 hp @ 6000 rpm                  4 Speed  ...    NaN
#   19              5.96 kW / 7.99 hp                  3-Speed  ...    NaN
#   20   8.5 kW / 11.4 hp @ 10500 rpm                  5-Speed  ...    NaN
#   21    7.5 kW / 10.0 hp @ 8500 rpm                  5-Speed  ...    NaN
#   22               3.7 kW / 4.98 hp  4 Speed, Burman gearbox  ...    NaN
#   23     7.1 kW / 9.5 hp @ 8500 rpm                  5-Speed  ...    NaN
#   24                            NaN                      NaN  ...    NaN
#   25                            NaN                      NaN  ...    NaN
#   26                            NaN                      NaN  ...    NaN
#   27                            NaN                      NaN  ...    NaN
#   28                            NaN                      NaN  ...    NaN
#   29                            NaN                      NaN  ...    NaN
#   30                            NaN                      NaN  ...    NaN
#   31                            NaN                      NaN  ...    NaN
#
#                                               Dryweight     Source  \
#   0                                                 NaN        NaN
#   1                                                 NaN        NaN
#   2                                                 NaN        NaN
#   3                                                 NaN        NaN
#   4                                                 NaN        NaN
#   5                                                 NaN        NaN
#   6                                                 NaN        NaN
#   7                                                 NaN        NaN
#   8                                                 NaN        NaN
#   9                                                 NaN        NaN
#   10                                                NaN        NaN
#   11                                                NaN        NaN
#   12                                                NaN        NaN
#   13                                                NaN        NaN
#   14                                   173 kg / 381 lbs  Wikipedia
#   15  Standard rigid frame: 15660 kg / 353 lbs Sprin...        NaN
#   16                                                NaN        NaN
#   17                                                NaN        NaN
#   18                                                NaN        NaN
#   19                                                NaN        NaN
# ...
#   15                                  113 km/h / 70 mph
#   16                                  113 km/h / 70 mph
#   17                                  113 km/h / 70 mph
#   18                                                NaN
#   19                                  121 km/h / 75 mph
#   20                                  121 km/h / 75 mph
#   21                                                NaN
#   22                                                NaN
#   23                                                NaN
#   24                                                NaN
#   25                                                NaN
#   26                                                NaN
#   27                                                NaN
#   28                                                NaN
#   29                                  129 km/h / 80 mph
#   30  ZF 9.8: 129 km/h / 80 mph ZF 13.0: 137 km/h / ...
#   31  ZF 6.5: 129 km/h / 80 mph ZF 13.0: 137 km/h / ...
#   32                                                NaN
#   33                                  137 km/h / 85 mph
#   34                                  153 km/h / 95 mph
#   35                                  153 km/h / 95 mph
#   36                                                NaN
#   37                                                NaN
#   38                                                NaN
#   39                                                NaN
#
#                 Maximum Combined Range City And Highway  \
#   0                                                 NaN
#   1                                                 NaN
#   2                                                 NaN
#   3                                                 NaN
#   4                                                 NaN
#   5                                                 NaN
#   6   ZF9.8: 114 - 134 km / 71 - 83 miles ZF 13.0: 1...
#   7                                                 NaN
#   8   ZF 13.0: 153- 177 km / 95 - 110 miles ZF 13.0 ...
#   9                                                 NaN
#   10  ZF 13.0: 153- 177 km / 95 - 110 miles ZF 13.0 ...
#   11                                                NaN
#   12                                                NaN
#   13                                                NaN
#   14                                                NaN
#   15                                                NaN
#   16  ZF 3.3: 39 - 50 km / 24- 31 miles ZF 6.5: 79 -...
#   17  ZF 3.3: 39 - 50 km / 24- 31 miles ZF 6.5: 79 -...
#   18                                                NaN
#   19  ZF 3.3: 39 - 50 km / 24- 31 miles ZF 6.5: 79 -...
#   20  ZF 3.3: 42 - 55 km / 26- 34 miles ZF 6.5: 84 -...
#   21                                                NaN
#   22                                                NaN
#   23                                                NaN
#   24                                                NaN
#   25                                                NaN
#   26                                                NaN
#   27                                                NaN
#   28                                                NaN
#   29                                                NaN
#   30                                                NaN
#   31                                                NaN
#   32                                                NaN
#   33                                                NaN
#   34  ZF 13.0: 174 - 196 km / 108 - 122 miles ZF 13....
#   35  ZF 13.0: 174 - 196 km / 108 - 122 miles ZF 13....
#   36                                                NaN
#   37                                                NaN
#   38                                                NaN
#   39                                                NaN
#
#                        Acceleration 0 100 Km/H / 60 Mph  \
#   0                                                 NaN
#   1                                                 NaN
#   2                                                 NaN
#   3                                                 NaN
#   4                                                 NaN
#   5                                                 NaN
#   6   ZF 9.8: 5.2 sec ZF 13.0: 5.7 sec ZF 13.0 + Pow...
#   7                                                 NaN
#   8      ZF 13.0: 3.9 sec ZF 13.0 + Power tank: 4.5 sec
#   9                                                 NaN
#   10     ZF 13.0: 3.9 sec ZF 13.0 + Power tank: 4.5 sec
#   11                                                NaN
#   12                                                NaN
#   13                                                NaN
#   14                                                NaN
#   15                                                NaN
#   16                    ZF 3.3: 4.3 sec ZF 6.5: 4.0 sec
#   17                    ZF 3.3: 4.3 sec ZF 6.5: 4.0 sec
#   18                                                NaN
#   19                    ZF 3.3: 4.1 sec ZF 6.5: 3.8 sec
#   20                    ZF 3.3: 4.1 sec ZF 6.5: 3.8 sec
#   21                                                NaN
#   22                                                NaN
#   23                                                NaN
#   24                                                NaN
#   25                                                NaN
#   26                                                NaN
#   27                                                NaN
#   28                                                NaN
#   29                                                NaN
#   30  ZF 9.8: 4.8 sec ZF 12.5: 5.2 sec ZF 12.5 + Pow...
#   31  ZF 9.8: 4.8 sec ZF 12.5: 5.2 sec ZF 12.5 + Pow...
#   32                                                NaN
#   33                                                NaN
#   34     ZF 13.0: 3.3 sec ZF 13.0 + Power pack: 3.9 sec
#   35     ZF 13.0: 3.3 sec ZF 13.0 + Power pack: 3.9 sec
#   36                                                NaN
#   37                                                NaN
#   38                                                NaN
#   39                                                NaN
#
#                              With Charge Tank Accessory  \
#   0                                                 NaN
#   1                                                 NaN
#   2                                                 NaN
#   3                                                 NaN
#   4                                                 NaN
#   5                                                 NaN
#   6                                                 NaN
#   7   ZF 6.5: 1.9 hrs (95%: 1.4 hrs) ZF 13.0: 3.4 hr...
#   8                                                 NaN
#   9   ZF 6.5: 1.9 hrs (95%: 1.4 hrs) ZF 13.0: 3.4 hr...
#   10                                                NaN
#   11                                                NaN
#   12                                                NaN
#   13                                                NaN
#   14                                                NaN
#   15                                                NaN
#   16                                                NaN
#   17                                                NaN
#   18                                                NaN
#   19                                                NaN
#   20                                                NaN
#   21                                                NaN
#   22                                                NaN
#   23                                                NaN
#   24                                                NaN
#   25                                                NaN
#   26                                                NaN
#   27                                                NaN
#   28                                                NaN
#   29                                                NaN
#   30                                                NaN
#   31  ZF 6.5: 1.9 hrs (95%: 1.4 hrs) ZF 13.0: 3.4 hr...
#   32                                                NaN
#   33                                                NaN
#   34                                                NaN
#   35  ZF 13.0: 3.4 hrs ( 95%: 2.9 hrs) ZF 13.0 + Pow...
#   36                                                NaN
#   37                                                NaN
#   38                                                NaN
#   39                                                NaN
#
#          Maximum Combined Range 89 113 Km/H / 55 70 Mph                  Input  \
#   0                                                 NaN                    NaN
#   1                                                 NaN                    NaN
#   2                                                 NaN                    NaN
#   3                                                 NaN                    NaN
#   4                                                 NaN                    NaN
#   5                                                 NaN                    NaN
#   6                                                 NaN                    NaN
#   7   ZF 6.5: 76 - 89 km / 47 - 55 miles ZF 13.0: 15...  Standard 110V or 220V
#   8                                                 NaN                    NaN
#   9   ZF 13.0: 153 - 177 km / 95 - 110 miles ZF 13.0...  Standard 110V or 220V
#   10                                                NaN                    NaN
#   11                                                NaN                    NaN
#   12                                                NaN                    NaN
#   13                                                NaN                    NaN
#   14                                                NaN                    NaN
#   15                                                NaN                    NaN
#   16                                                NaN                    NaN
#   17                                                NaN                    NaN
#   18                                                NaN                    NaN
#   19                                                NaN                    NaN
#   20                                                NaN                    NaN
#   21                                                NaN                    NaN
#   22                                                NaN                    NaN
#   23                                                NaN                    NaN
#   24                                                NaN                    NaN
#   25                                                NaN                    NaN
#   26                                                NaN                    NaN
#   27                                                NaN                    NaN
#   28                                                NaN                    NaN
#   29                                                NaN                    NaN
#   30  ZF9.8: 130 - 146 km / 81 - 91 miles ZF 13.0: 1...  Standard 110V or 220V
#   31  ZF 6.5: 87 - 98 km / 54 - 61 miles ZF 13.0: 17...  Standard 110V or 220V
#   32                                                NaN                    NaN
#   33                                                NaN                    NaN
#   34                                                NaN                    NaN
#   35                                                NaN                    NaN
#   36                                                NaN                    NaN
#   37                                                NaN                    NaN
#   38                                                NaN                    NaN
#   39                                                NaN                    NaN
#
#        Economy City Equivalent Fuel Economy  \
#   0                                     NaN
#   1                                     NaN
#   2                                     NaN
#   3                                     NaN
#   4                                     NaN
#   5                                     NaN
#   6                                     NaN
#   7                                     NaN
#   8                                     NaN
#   9                                     NaN
#   10                                    NaN
#   11                                    NaN
#   12                                    NaN
#   13                                    NaN
#   14                                    NaN
#   15                                    NaN
#   16                                    NaN
#   17                                    NaN
#   18                                    NaN
#   19                                    NaN
#   20                                    NaN
#   21                                    NaN
#   22                                    NaN
#   23                                    NaN
#   24                                    NaN
#   25                                    NaN
#   26                                    NaN
#   27                                    NaN
#   28                                    NaN
#   29                                    NaN
#   30  0.50 L/100 km / 200 km/l / 475 US mpg
#   31                                    NaN
#   32                                    NaN
#   33                                    NaN
#   34  0.50 L/100 km / 200 km/l / 475 US mpg
#   35  0.50 L/100 km / 200 km/l / 475 US mpg
#   36                                    NaN
#   37                                    NaN
#   38                                    NaN
#   39                                    NaN
#
#      Economy Highway Equivalent Fuel Economy
#   0                                      NaN
#   1                                      NaN
#   2                                      NaN
#   3                                      NaN
#   4                                      NaN
#   5                                      NaN
#   6                                      NaN
#   7                                      NaN
#   8                                      NaN
#   9                                      NaN
#   10                                     NaN
#   11                                     NaN
#   12                                     NaN
#   13                                     NaN
#   14                                     NaN
#   15                                     NaN
#   16                                     NaN
#   17                                     NaN
#   18                                     NaN
#   19                                     NaN
#   20                                     NaN
#   21                                     NaN
#   22                                     NaN
#   23                                     NaN
#   24                                     NaN
#   25                                     NaN
#   26                                     NaN
#   27                                     NaN
#   28                                     NaN
#   29                                     NaN
#   30   0.98 L/100 km / 102 km/l / 240 US mpg
#   31                                     NaN
#   32                                     NaN
#   33                                     NaN
#   34   0.98 L/100 km / 102 km/l / 240 US mpg
#   35   0.98 L/100 km / 102 km/l / 240 US mpg
#   36                                     NaN
#   37                                     NaN
#   38                                     NaN
#   39                                     NaN
#
#   [40 rows x 55 columns]}]

# %% [markdown]
# ## WARNING: THE CODE BELOW PROCESSES ALL 11k MODELS AND SAVES TO OVER 100 CSV FILES

# %%
all_tables = []
for i, mfct_name in enumerate([m['mfct'] for m in mfct_urls]):
    print("Processing", i,"of",len(mfct_urls)-1,":",mfct_name)
    cleaned_tables = get_all_model_tables_for_mfct(mfct_name)
    all_tables.extend(cleaned_tables)
    df = pd.DataFrame(cleaned_tables)
    mfct_urls[i]['df'] = df
    df.to_csv("models {index:03d} - {mfct_name}.csv".format(index = i, mfct_name=urllib.parse.quote(mfct_name,'')))
# Out:
# Processing 0 of 132 : AC Schnitzer
# Processing 1 of 132 : Adler
# Processing 2 of 132 : AJP
# Processing 3 of 132 : AJS
# Processing 4 of 132 : Alfer
# Processing 5 of 132 : Aprilia
# Overwriting key Final Drive old value: Chain new value 17:40 for https://www.motorcyclespecs.co.za/model/aprilia/aprilia-rs125r-nero-06.html
# Overwriting key Final Drive old value: Chain new value 17:40 for https://www.motorcyclespecs.co.za/model/aprilia/aprilia-rs125r-06.html
# Overwriting key Final Drive old value: Chain new value 17:40 for https://www.motorcyclespecs.co.za/model/aprilia/aprilia-rs125r-07.html
# Overwriting key Final Drive old value: Chain new value 17:40 for https://www.motorcyclespecs.co.za/model/aprilia/aprilia-rs125-lorenzo-07.html
# Overwriting key Final Drive old value: Chain new value 17:40 for https://www.motorcyclespecs.co.za/model/aprilia/aprilia-rs125r-08.html
# Overwriting key Final Drive old value: Chain new value 17:40 for https://www.motorcyclespecs.co.za/model/aprilia/aprilia-rs125r-rosso-fluo.html
# Overwriting key Final Drive old value: Chain new value 17:40 for https://www.motorcyclespecs.co.za/model/aprilia/aprilia-rs125-standerd-09.html
# Overwriting key Final Drive old value: Chain new value 17:40 for https://www.motorcyclespecs.co.za/model/aprilia/aprilia-rs125r-09.html
# Overwriting key Final Drive old value: Chain new value 17:40 for https://www.motorcyclespecs.co.za/model/aprilia/aprilia-rs125-talmacsi-rep.html
# Overwriting key Final Drive old value: Chain new value 17:40 for https://www.motorcyclespecs.co.za/model/aprilia/aprilia-rs125r-max-biaggi.html
# Overwriting key Final Drive old value: Chain new value 17:40 for https://www.motorcyclespecs.co.za/model/aprilia/aprilia-rs125r-10.html
# Overwriting key Final Drive old value: Chain new value 17:40 for https://www.motorcyclespecs.co.za/model/aprilia/aprilia-rs125r-full-black.html
# Overwriting key Final Drive old value: Chain new value 17:40 for https://www.motorcyclespecs.co.za/model/aprilia/aprilia-rs125r-full-white.html
# Overwriting key Final Drive old value: Chain new value 17:40 for https://www.motorcyclespecs.co.za/model/aprilia/aprilia-rs125r-10%20biagie%20rep.html
# Processing 6 of 132 : Ariel
# Processing 7 of 132 : Arlen Ness
# Woah more than one table at https://www.motorcyclespecs.co.za/model/Victory/victory_vision_Arlen%20Ness%2010.htm
# Processing 8 of 132 : ATK
# Processing 9 of 132 : Avinton / Wakan
# Processing 10 of 132 : Bajai
# Processing 11 of 132 : Bakker
# Processing 12 of 132 : Barigo
# Processing 13 of 132 : Benelli
# Processing 14 of 132 : Beta
# Processing 15 of 132 : Big Bear
# Processing 16 of 132 : Big Dog
# Processing 17 of 132 : Bimota
# Overwriting key Seat Height old value: 800mm / 31.5 in. new value 790 mm / 31.1 in. for https://www.motorcyclespecs.co.za/model/bimota/bimota-db5.html
# Overwriting key Seat Height old value: 800mm / 31.5 in. new value 790 mm / 31.1 in. for https://www.motorcyclespecs.co.za/model/bimota/bimota-db5-07.html
# Overwriting key Cooling System old value: Liquid cooled new value Liquid for https://www.motorcyclespecs.co.za/model/bimota/bimota_sb8k%2004.htm
# Overwriting key Cooling System old value: Liquid cooled new value Liquid for https://www.motorcyclespecs.co.za/model/bimota/bimota_sb8k_santa_monica.htm
# Processing 18 of 132 : BMS Choppers
# Processing 19 of 132 : BMW
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/bmw/bmw-r1200r-17.html
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/bmw/bmw-r1200r-17.html
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/bmw/bmw-r1200r-18.html
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/bmw/bmw-r1200r-18.html
# Processing 20 of 132 : Boss Hoss
# Processing 21 of 132 : Boxer
# Processing 22 of 132 : Brammo
# Processing 23 of 132 : Britten
# Processing 24 of 132 : Brixton Motorcycles
# Processing 25 of 132 : Brough Superior Motorcycles
# Processing 26 of 132 : BRP Cam-Am
# Processing 27 of 132 : BSA
# Processing 28 of 132 : Buell / EBR
# Processing 29 of 132 : Bultaco
# Processing 30 of 132 : Cagiva
# Processing 31 of 132 : Campagna
# Processing 32 of 132 : CCM
# Processing 33 of 132 : CF Moto
# Processing 34 of 132 : Confederate / Combat Motors
# Processing 35 of 132 : CR&S
# Processing 36 of 132 : CZ Motorcycles
# Processing 37 of 132 : Daelim
# Processing 38 of 132 : Derbi
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/Derbi/Derbi_Mulachen_Cafe_07.html
# Processing 39 of 132 : Deus
# Processing 40 of 132 : DP Customs
# Processing 41 of 132 : Ducati
# Overwriting key Final Drive old value: Chain new value 2.706 for https://www.motorcyclespecs.co.za/model/ducati/ducati_98_sport_53.htm
# Overwriting key Final Drive old value: Chain new value 3.066:1 for https://www.motorcyclespecs.co.za/model/ducati/Ducati_175_Americano.html
# Overwriting key Final Drive old value: Chain new value 3.066:1 for https://www.motorcyclespecs.co.za/model/ducati/Ducati_175_ts.html
# Overwriting key Final Drive old value: Chain new value 3.066:1 for https://www.motorcyclespecs.co.za/model/ducati/Ducati_175_ts_64.html
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/ducati/ducati_diavel%20Strada%2013.htm
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/ducati/ducati_diavel%20Strada%2013.htm
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/ducati/ducati_diavel%20strada%2014.htm
# Overwriting key Exhaust old value: 2-1 system with catalytic converter and two
# lambda  probes, Single stainless steel muffler with new value Lightweight 2-1-2 system with catalytic
# converter with twin lambda probes for https://www.motorcyclespecs.co.za/model/ducati/ducati_monster_797_17.htm
# Overwriting key Exhaust old value: 2-1 system with catalytic converter and two
# lambda  probes, Single stainless steel muffler with new value Lightweight 2-1-2 system with catalytic
# converter with twin lambda probes for https://www.motorcyclespecs.co.za/model/ducati/ducati_monster_797_se_18.html
# Overwriting key Exhaust old value: 2-1 system with catalytic converter and two
# lambda  probes, Single stainless steel muffler with new value Lightweight 2-1-2 system with catalytic
# converter with twin lambda probes for https://www.motorcyclespecs.co.za/model/ducati/ducati_monster_797+_18.html
# Overwriting key Exhaust old value: 2-1 system with catalytic converter and two
# lambda  probes, Single stainless steel muffler with new value Lightweight 2-1-2 system with catalytic
# converter with twin lambda probes for https://www.motorcyclespecs.co.za/model/ducati/ducati_monster_797_19.html
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/ducati/ducati_multistrada_950S_20_gp_white.html
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/ducati/ducati_multistrada_1200%20S%2010.htm
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/ducati/ducati_multistrada_1200%20S%2011.htm
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/ducati/ducati_multistrada_1200%20S%20pikes%20peak.htm
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/ducati/ducati_multistrada_1200%20S%2012.htm
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/ducati/ducati_multistrada_1200%20S%20pikes%20peak%2012.htm
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/ducati/ducati_multistrada_1200%20S%2013.htm
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/ducati/Ducati_Multistrada_1200S_Touring_13.html
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/ducati/ducati_multistrada_1200%20S%20GT%2013.htm
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/ducati/ducati_multistrada_1200%20S%20pikes%20peak%2013.htm
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/ducati/ducati_multistrada_1200%20SDolomites%20Peak%20Edition.htm
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/ducati/ducati_multistrada_1200%20S%2014.htm
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/ducati/Ducati_Multistrada_1200S_Touring_14.html
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/ducati/ducati_multistrada_1200%20S%20GT%2014.htm
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/ducati/ducati_multistrada_1200%20S%20pikes%20peak%2014.htm
# Processing 42 of 132 : Excelsior
# Processing 43 of 132 : Exile
# Processing 44 of 132 : GASGAS
# Processing 45 of 132 : Ghezzi Brian
# Processing 46 of 132 : Gilera
# Processing 47 of 132 : GIMA
# Processing 48 of 132 : Harley-Davidson
# Processing 49 of 132 : Harris
# Processing 50 of 132 : Hartford
# Processing 51 of 132 : HDT USA
# Processing 52 of 132 : Hesketh
# Processing 53 of 132 : Hero
# Processing 54 of 132 : Highland
# Processing 55 of 132 : Honda
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr600rr_se_09.html
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/Honda/honda_cbr1100xx_97.html
# Overwriting key Standing ¼ Mile old value: 11.1 sec / 193.0 km/h new value 11.4 sec for https://www.motorcyclespecs.co.za/model/Honda/honda_vfr800_02.html
# Overwriting key Consumption Average old value: 15.9 km/lit new value 18.0 km/lot for https://www.motorcyclespecs.co.za/model/Honda/honda_vfr800_abs_03.html
# Overwriting key Standing ¼ Mile old value: 11.1 sec / 193.0 km/h new value 11.4 sec for https://www.motorcyclespecs.co.za/model/Honda/honda_vfr800_abs_03.html
# Overwriting key Consumption Average old value: 15.9 km/lit new value 18.0 km/lot for https://www.motorcyclespecs.co.za/model/Honda/honda_vfr800_abs_04.html
# Overwriting key Standing ¼ Mile old value: 11.1 sec / 193.0 km/h new value 11.4 sec for https://www.motorcyclespecs.co.za/model/Honda/honda_vfr800_abs_04.html
# Overwriting key Standing ¼ Mile old value: 11.1 sec / 193.0 km/h new value 11.4 sec for https://www.motorcyclespecs.co.za/model/Honda/honda_vfr800_abs_05.html
# Overwriting key Standing ¼ Mile old value: 11.1 sec / 193.0 km/h new value 11.4 sec for https://www.motorcyclespecs.co.za/model/Honda/honda_vfr800_vtec_06.html
# Processing 56 of 132 : Horex
# Processing 57 of 132 : HPN
# Processing 58 of 132 : Husaberg
# Processing 59 of 132 : Husqvarna
# Processing 60 of 132 : Hyosung
# Processing 61 of 132 : Indian
# Processing 62 of 132 : Italjet
# Processing 63 of 132 : Jawa
# Processing 64 of 132 : Junak
# Processing 65 of 132 : Kawasaki
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/kawasaki/kawasaki_s3_400%2075.htm
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/kawasaki/kawasaki_s3_400%2075.htm
# Overwriting key Ground Clearance old value: 1435 mm / 56.5 in. new value 125 mm / 4.9 in for https://www.motorcyclespecs.co.za/model/kawasaki/kawasaki_z1000r_17.htm
# Overwriting key Ground Clearance old value: 1435 mm / 56.5 in. new value 125 mm / 4.9 in for https://www.motorcyclespecs.co.za/model/kawasaki/kawasaki_z1000r_19.html
# Processing 66 of 132 : KTM
# Processing 67 of 132 : KYMCO
# Processing 68 of 132 : Laverda
# Processing 69 of 132 : Lazareth
# Processing 70 of 132 : Lehman Trikes
# Processing 71 of 132 : LIFAN
# Processing 72 of 132 : Lord Drake Kustoms
# Processing 73 of 132 : Magni
# Processing 74 of 132 : Maico
# Overwriting key Fuel System old value: Carburetor new value Carburetor for https://www.motorcyclespecs.co.za/model/Maico/Maico%20GS%20600.htm
# Processing 75 of 132 : Mash
# Processing 76 of 132 : Matchless
# Processing 77 of 132 : Matt Hotch
# Processing 78 of 132 : Megelli
# Processing 79 of 132 : Midual
# Processing 80 of 132 : Mission
# Processing 81 of 132 : Molot
# Processing 82 of 132 : Mondial
# Processing 83 of 132 : Moto Guzzi
# Processing 84 of 132 : Moto Morini
# Overwriting key Consumption Average old value: 18.1 km/lit new value 18.1 km/lit for https://www.motorcyclespecs.co.za/model/Moto%20Morini/moto_morini_granpasso_1200%2009.htm
# Overwriting key Consumption Average old value: 18.1 km/lit new value 18.1 km/lit for https://www.motorcyclespecs.co.za/model/Moto%20Morini/moto_morini_granpasso_1200%20kit%2009.htm
# Overwriting key Consumption Average old value: 18.1 km/lit new value 18.1 km/lit for https://www.motorcyclespecs.co.za/model/Moto%20Morini/moto_morini_granpasso_H83%2010.htm
# Processing 85 of 132 : Mr Martini
# Processing 86 of 132 : MTT
# Processing 87 of 132 : Münch
# Processing 88 of 132 : MV Agusta
# Overwriting key Electronic Quickshift old value: MV EAS 3.0 (Electronically Assisted Shift up & down) new value MV EAS 2.0 (Electronically Assisted Shift up & down) for https://www.motorcyclespecs.co.za/model/mv/mv_agusta_brutale_800_ross_21.html
# Overwriting key Electronic Quickshift old value: MV EAS 3.0 (Electronically Assisted Shift up & down) new value MV EAS 2.0 (Electronically Assisted Shift up & down) for https://www.motorcyclespecs.co.za/model/mv/mv_agusta_brutale_800rr_21.html
# Overwriting key Electronic Quickshift old value: MV EAS 3.0 (Electronically Assisted Shift up & down) new value MV EAS 2.0 (Electronically Assisted Shift up & down) for https://www.motorcyclespecs.co.za/model/mv/mv_agusta_brutale_800rr_scs_21.html
# Overwriting key Electronic Quickshift old value: MV EAS 3.0 (Electronically Assisted Shift up & down) new value MV EAS 2.0 (Electronically Assisted Shift up & down) for https://www.motorcyclespecs.co.za/model/mv/mv_agusta_dragster_800_rosso_21.html
# Overwriting key Electronic Quickshift old value: MV EAS 3.0 (Electronically Assisted Shift up & down) new value MV EAS 2.0 (Electronically Assisted Shift up & down) for https://www.motorcyclespecs.co.za/model/mv/mv_agusta_dragster_800rr_21.html
# Overwriting key Electronic Quickshift old value: MV EAS 3.0 (Electronically Assisted Shift up & down) new value MV EAS 2.0 (Electronically Assisted Shift up & down) for https://www.motorcyclespecs.co.za/model/mv/mv_agusta_dragster_800rr_scs_21.html
# Overwriting key Electronic Quickshift old value: MV EAS 3.0 (Electronically Assisted Shift up & down) new value MV EAS 2.0 (Electronically Assisted Shift up & down) for https://www.motorcyclespecs.co.za/model/mv/mv_agusta_dragster_800rr_scs_london_sp.html
# Overwriting key Electronic Quickshift old value: MV EAS 3.0 (Electronically Assisted Shift up & down) new value MV EAS 2.0 (Electronically Assisted Shift up & down) for https://www.motorcyclespecs.co.za/model/mv/mv_agusta_dragster_800rc_scs_21.html
# Overwriting key Electronic Quickshift old value: MV EAS 3.0 (Electronically Assisted Shift up & down) new value MV EAS 2.0 (Electronically Assisted Shift up & down) for https://www.motorcyclespecs.co.za/model/mv/mv-agusta-dragster-800rc-scs-22.html
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/mv/mv-agusta-f3-800rc-22.html
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/mv/mv-agusta-f3-800rc-22.html
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/mv/mv_agusta_F4_Claudio.html
# Processing 89 of 132 : MZ / MuZ
# Processing 90 of 132 : NCR
# Processing 91 of 132 : Norton
# Processing 92 of 132 : NSU
# Processing 93 of 132 : OCC
# Processing 94 of 132 : Paton
# Processing 95 of 132 : Paul Jr. Designs
# Processing 96 of 132 : Peugeot
# Processing 97 of 132 : Piaggio
# Processing 98 of 132 : Revival Cycles
# Processing 99 of 132 : Rickman
# Processing 100 of 132 : Roehr
# Processing 101 of 132 : Roland Sands
# Processing 102 of 132 : Royal Enfield
# Processing 103 of 132 : Rucker
# Processing 104 of 132 : Sachs
# Processing 105 of 132 : Saxon
# Processing 106 of 132 : Shaw Speed
# Processing 107 of 132 : Sherco
# Processing 108 of 132 : Sunbeam
# Processing 109 of 132 : Suzuki
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/suzu/suzuki_gt250%2076.htm
# Overwriting key Final Drive old value: Shaft new value 32/12 (2.6) for https://www.motorcyclespecs.co.za/model/suzu/suzuki_gv1400_cavalcade_gt.htm
# Overwriting key Final Drive old value: Shaft new value 32/12 (2.6) for https://www.motorcyclespecs.co.za/model/suzu/suzuki_gv1400_cavalcade_lx.htm
# Overwriting key Final Drive old value: Shaft new value 32/12 (2.6) for https://www.motorcyclespecs.co.za/model/suzu/suzuki_gv1400_lxe_cavalcade%2087.htm
# Processing 110 of 132 : SWM
# Processing 111 of 132 : SYM
# Processing 112 of 132 : Titan
# Processing 113 of 132 : TM Racing
# Processing 114 of 132 : Triumph
# We found more than 2 columns on page https://www.motorcyclespecs.co.za/model/triu/Triumph_Street_Twin_19.html
# Processing 115 of 132 : TVS
# Processing 116 of 132 : Ural
# Processing 117 of 132 : Velocette
# Processing 118 of 132 : Vespa
# Overwriting key Seat Height old value: 775 mm / 30.5 in new value 805 mm / 31.7 in for https://www.motorcyclespecs.co.za/model/Vespa/Vespa%20LX%2050%202T%2006.htm
# Overwriting key Seat Height old value: 775 mm / 30.5 in new value 775 mm / 30.5 in for https://www.motorcyclespecs.co.za/model/Vespa/Vespa%20LX50%204T%2006.htm
# Processing 119 of 132 : Victory
# Woah more than one table at https://www.motorcyclespecs.co.za/model/Victory/victory_vision_Arlen%20Ness%2010.htm
# Processing 120 of 132 : Vilner
# Processing 121 of 132 : Vincent
# Processing 122 of 132 : VOR
# Processing 123 of 132 : Voxan
# Woah more than one table at https://www.motorcyclespecs.co.za/model/voxan/Voxan_GTV_1200.html
# Processing 124 of 132 : Vyrus
# Processing 125 of 132 : Walt Siegl
# Processing 126 of 132 : Walz
# Processing 127 of 132 : Wrenchmonkees
# Processing 128 of 132 : Wunderlich
# Processing 129 of 132 : XTR / Radical
# Processing 130 of 132 : Yamaha
# Processing 131 of 132 : Zero

# %% [markdown]
# # Combine all the tables into one giant table

# %%
df = pd.DataFrame(all_tables)

# %% [markdown]
# # Export to CSV

# %%
df.to_csv('ALL_MODELS.csv')

# %% [markdown]
# # Export to Excel
#
# Install the dependencies
#
# > pip install XlsxWriter

# %%
#with pd.ExcelWriter("ALL_MODELS.xlsx") as writer:
#    df.to_excel(writer, sheet_name="models", index=False)

with pd.ExcelWriter("models_on_sheets.xlsx") as writer:
    for m in mfct_urls:
        m['df'].to_excel(writer, sheet_name=urllib.parse.quote(m['mfct'],'')[0:31], index=False)

# %% [markdown]
# # Debugging

# %%
url = "https://www.motorcyclespecs.co.za/model/voxan/Voxan_GTV_1200.html"
raw_html = retrieve_and_cache(url)
table_dict = parse_table_to_dict(raw_html,url=url)
# Out:
# Woah more than one table at https://www.motorcyclespecs.co.za/model/voxan/Voxan_GTV_1200.html
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[133], line 3
#       1 url = "https://www.motorcyclespecs.co.za/model/voxan/Voxan_GTV_1200.html"
#       2 raw_html = retrieve_and_cache(url)
# ----> 3 table_dict = parse_table_to_dict(raw_html,url=url)
#
# Cell In[128], line 63, in parse_table_to_dict(text, url)
#      61 hook = hook[0] # For now we're only parsing the first one.
#      62 table = hook.find_parent('table')
# ---> 63 rows = table.find_all('tr')
#      64 assert(len(rows) > 1) # Assert we've found and parsed a table with many rows
#      66 # Extract the key:value pairs
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
soup = BeautifulSoup(raw_html, 'lxml') # important to pip install lxml
output = {}

# Find the Table
hook = soup.find_all(string=re.compile(".*Make Model.*"))
if len(hook) > 1:
    print("Woah more than one table at",url)
assert(len(hook)>=1)  # Assert we find at least one NavigatableString containing "Make Model"
for h in hook:
    if h.find_parent('table'):
        table = h.find_parent('table')
        break
table
# Out:
# Woah more than one table at https://www.motorcyclespecs.co.za/model/voxan/Voxan_GTV_1200.html
# <table height="821" id="table8" width="100%">
# <tr>
# <td class="xl24" height="39" style="border-style: solid" width="618">
# <p align="justify"><font face="Arial">Make Model</font></p></td>
# <td class="xl25" height="38" style="border-left-style: solid; border-left-width: medium; border-right-style: solid; border-top-style: solid; border-bottom-style: solid" width="1230">
# <font face="Arial">Voxan GTV 1200</font></td>
# </tr>
# <tr>
# <td class="xl24" height="39" style="border-left-style: solid; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="618">
# <p align="justify"><font face="Arial">Year</font></p></td>
# <td class="xl26" height="38" style="border-left-style: solid; border-left-width: medium; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="1230" x:num="">
# <font face="Arial">2010</font></td>
# </tr>
# <tr>
# <td class="xl24" height="39" style="border-left-style: solid; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="618">
# <p align="justify"><font face="Arial">Engine</font></p></td>
# <td class="xl26" height="38" style="border-left-style: solid; border-left-width: medium; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="1230">
# <font face="Arial">Four stoke, 72°V-Twin</font></td>
# </tr>
# <tr>
# <td class="xl24" height="39" style="border-left-style: solid; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="618">
# <p align="justify"><font face="Arial">Capacity</font></p></td>
# <td class="xl26" height="38" style="border-left-style: solid; border-left-width: medium; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="1230" x:num="">
# <font face="Arial">1166.5 cc</font></td>
# </tr>
# <tr>
# <td class="xl24" height="39" style="border-left-style: solid; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="618">
# <span style="font-weight: normal; font-family: Courier New">
# <font face="Arial">Bore x Stroke</font></span></td>
# <td class="xl27" height="38" style="border-left-style: solid; border-left-width: medium; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="1230">
# <font face="Arial">103 x 107 mm</font></td>
# </tr>
# <tr>
# <td class="xl24" height="39" style="border-left-style: solid; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="618">
#     Cooling System</td>
# <td class="xl27" height="38" style="border-left-style: solid; border-left-width: medium; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="1230">
# <font face="Arial">Liquid cooled</font></td>
# </tr>
# <tr>
# <td class="xl24" height="39" style="border-left-style: solid; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="618">
# <span style="font-weight: normal; font-family: Courier New">
# <font face="Arial">Compression Ratio</font></span></td>
# <td class="xl27" height="38" style="border-left-style: solid; border-left-width: medium; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="1230">
#     NA</td>
# </tr>
# <tr>
# <td class="xl24" height="39" style="border-left-style: solid; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="618">
# <p align="justify"><font face="Arial">Induction</font></p></td>
# <td class="xl27" height="38" style="border-left-style: solid; border-left-width: medium; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="1230">
# <font face="Arial">Electronically controlled fuel injectioned fuel
# 	injection</font></td>
# </tr>
# <tr>
# <td class="xl28" height="39" style="border-left-style: solid; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="618">
# <p align="justify"><font face="Arial">Ignition </font></p></td>
# <td class="xl26" height="39" style="border-left-style: solid; border-left-width: medium; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="1230">
# <font face="Arial">Electronic </font></td>
# </tr>
# <tr>
# <td class="xl24" height="39" style="border-left-style: solid; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="618">
# <font face="Arial">Starting</font></td>
# <td class="xl26" height="39" style="border-left-style: solid; border-left-width: medium; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="1230">
#     Electric</td>
# </tr>
# <tr>
# <td class="xl24" height="39" style="border-left-style: solid; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="618">
# <p align="justify"><font face="Arial">Max Power</font></p></td>
# <td class="xl26" height="39" style="border-left-style: solid; border-left-width: medium; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="1230">
# <font face="Arial">106 hp</font></td>
# </tr>
# <tr>
# <td class="xl24" height="39" style="border-left-style: solid; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="618">
# <p align="justify"><font face="Arial">Max Torque</font></p></td>
# <td class="xl26" height="39" style="border-left-style: solid; border-left-width: medium; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="1230">
#     NA</td>
# </tr>
# <tr>
# <td class="xl24" height="39" style="border-left-style: solid; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="618">
# <p align="justify"><font face="Arial">Transmission</font></p></td>
# <td class="xl26" height="39" style="border-left-style: solid; border-left-width: medium; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="1230">
# <font face="Arial">6 Speed </font></td>
# </tr>
# <tr>
# <td class="xl24" height="39" style="border-left-style: solid; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="618">
#     Final Drive</td>
# <td class="xl26" height="39" style="border-left-style: solid; border-left-width: medium; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="1230">
#     Belt</td>
# </tr>
# <tr>
# <td class="xl24" height="39" style="border-left-style: solid; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="618">
# <font face="Arial">Frame</font></td>
# <td class="xl26" height="39" style="border-left-style: solid; border-left-width: medium; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="1230">
# <font face="Arial">Trellis Frame</font></td>
# </tr>
# <tr>
# <td class="xl24" height="39" style="border-left-style: solid; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="618">
# <p align="justify"><font face="Arial">Front Suspension</font></p></td>
# <td class="xl26" height="39" style="border-left-style: solid; border-left-width: medium; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="1230">
# <font face="Arial">43mm Upside down hydraulic forks</font></td>
# </tr>
# <tr>
# <td class="xl24" height="39" style="border-left-style: solid; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="618">
# <p align="justify"><font face="Arial">Rear Suspension</font></p></td>
# <td class="xl26" height="39" style="border-left-style: solid; border-left-width: medium; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="1230">
#      </td>
# </tr>
# <tr>
# <td class="xl24" height="39" style="border-left-style: solid; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="618">
# <p align="justify"><font face="Arial">Front Brakes</font></p></td>
# <td class="xl26" height="39" style="border-left-style: solid; border-left-width: medium; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="1230">
# <font face="Arial">2x 320mm discs 4 piston calipers</font></td>
# </tr>
# <tr>
# <td class="xl24" height="39" style="border-left-style: solid; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="618">
# <p align="justify"><font face="Arial">Rear Brakes</font></p></td>
# <td class="xl26" height="39" style="border-left-style: solid; border-left-width: medium; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="1230">
# <font face="Arial">Single 245mm disc  2 piston caliper</font></td>
# </tr>
# <tr>
# <td class="xl24" height="39" style="border-left-style: solid; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="618">
# <p align="justify"><font face="Arial">Front Tyre</font></p></td>
# <td class="xl29" height="39" style="border-left-style: solid; border-left-width: medium; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="1230">
# <font face="Arial">120/70-17</font></td>
# </tr>
# <tr>
# <td class="xl24" height="39" style="border-left-style: solid; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="618">
# <p align="justify"><font face="Arial">Rear Tyre</font></p></td>
# <td class="xl29" height="39" style="border-left-style: solid; border-left-width: medium; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="1230">
# <font face="Arial">180/55-17</font></td>
# </tr>
# <tr>
# <td class="xl24" height="39" style="border-left-style: solid; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="618">
# <font face="Arial">Seat Height</font></td>
# <td class="xl26" height="39" style="border-left-style: solid; border-left-width: medium; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="1230">
#      </td>
# </tr>
# <tr>
# <td class="xl24" height="39" style="border-left-style: solid; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="618">
# <p align="justify"><font face="Arial">Dry Weight  </font></p></td>
# <td class="xl26" height="39" style="border-left-style: solid; border-left-width: medium; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="1230">
# <font face="Arial">179 kg</font></td>
# </tr>
# <tr>
# <td class="xl24" height="39" style="border-left-style: solid; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="618">
# <p align="justify"><font face="Arial">Fuel Capacity </font></p></td>
# <td class="xl26" height="39" style="border-left-style: solid; border-left-width: medium; border-right-style: solid; border-top-style: solid; border-top-width: medium; border-bottom-style: solid" width="1230">
# <font face="Arial">17 Litres</font></td>
# </tr>
# </table>

# %%
hook
# Out:
# ['Make Model', 'Make Model']

# %%
hook = hook[0] # For now we're only parsing the first one. 
table = hook.find_parent('table')
rows = table.find_all('tr')

# %%
import xlsxwriter

# %%
"hkjansdflkjnasdf"[0:31]
# Out:
# 'hkjansdflkjnasdf'
